# %%
import pandas as pd

train = pd.read_csv('~/Downloads/2025datathon/train.csv')
test = pd.read_csv('~/Downloads/2025datathon/test.csv')

# %% [markdown]
# - 목표: Deppession (이진 분류)
# - 데이터 특징: 범주형 + 수치형 + 민감 응답 혼합

# %% [markdown]
# ![image.png](attachment:1c3e2cbe-1bbe-489f-8bbe-9a0ebbbc152b.png)

# %% [markdown]
# ## 전처리

# %%
import pandas as pd
import numpy as np

train = pd.read_csv('~/Downloads/2025datathon/train.csv')
test = pd.read_csv('~/Downloads/2025datathon/test.csv')

# %% [markdown]
# ### 0. 삭제

# %%
train.drop(columns=['id'], inplace=True)
train.drop(columns=['Name'], inplace=True)

# %% [markdown]
# ### 1. Sleep Duration

# %% [markdown]
# - 기준을 만들어서 float 형으로 변환

# %%
train['Sleep Duration'].value_counts()
# Out:
# Sleep Duration
# Less than 5 hours    38784
# 7-8 hours            36969
# More than 8 hours    32726
# 5-6 hours            32142
# 3-4 hours               12
# 6-7 hours                8
# 4-5 hours                7
# 2-3 hours                5
# 4-6 hours                5
# 6-8 hours                4
# 1-6 hours                4
# No                       4
# 9-11 hours               2
# 10-11 hours              2
# Sleep_Duration           2
# Unhealthy                2
# 45                       2
# 8-9 hours                2
# 10-6 hours               1
# 9-5                      1
# 45-48 hours              1
# 3-6 hours                1
# Work_Study_Hours         1
# 49 hours                 1
# than 5 hours             1
# Pune                     1
# 9-6 hours                1
# 8 hours                  1
# 35-36 hours              1
# Indore                   1
# 1-3 hours                1
# 55-66 hours              1
# Moderate                 1
# 40-45 hours              1
# 1-2 hours                1
# 9-5 hours                1
# Name: count, dtype: int64

# %%
# 이상치, 알 수 없는 값들 제거
delete_values = [
    'Indore', 'Pune', 'Moderate', 'Unhealthy', 'Sleep_Duration',
    'Work_Study_Hours', 'No', '45', '49 hours', '55-66 hours', '40-45 hours', 
    '9-5 hours', '10-6 hours', '9-6 hours', '9-5', '45-48 hours', '35-36 hours'
]

train['Sleep Duration'] = train['Sleep Duration'].replace(delete_values, np.nan)
train['Sleep Duration_missing'] = train['Sleep Duration'].isnull().astype(int)
mode_val = train["Sleep Duration"].mode()[0]
train["Sleep Duration"] = train["Sleep Duration"].fillna(mode_val)

# %%
train['Sleep Duration'].value_counts()
# Out:
# Sleep Duration
# Less than 5 hours    38807
# 7-8 hours            36969
# More than 8 hours    32726
# 5-6 hours            32142
# 3-4 hours               12
# 6-7 hours                8
# 4-5 hours                7
# 2-3 hours                5
# 4-6 hours                5
# 1-6 hours                4
# 6-8 hours                4
# 8-9 hours                2
# 9-11 hours               2
# 10-11 hours              2
# 1-3 hours                1
# 1-2 hours                1
# 8 hours                  1
# than 5 hours             1
# 3-6 hours                1
# Name: count, dtype: int64

# %%
train
# Out:
#         Gender   Age           City Working Professional or Student  \
# 0       Female  49.0       Ludhiana            Working Professional
# 1         Male  26.0       Varanasi            Working Professional
# 2         Male  33.0  Visakhapatnam                         Student
# 3         Male  22.0         Mumbai            Working Professional
# 4       Female  30.0         Kanpur            Working Professional
# ...        ...   ...            ...                             ...
# 140695  Female  18.0      Ahmedabad            Working Professional
# 140696  Female  41.0      Hyderabad            Working Professional
# 140697  Female  24.0        Kolkata            Working Professional
# 140698  Female  49.0       Srinagar            Working Professional
# 140699    Male  27.0          Patna                         Student
#
#                Profession  Academic Pressure  Work Pressure  CGPA  \
# 0                    Chef                NaN            5.0   NaN
# 1                 Teacher                NaN            4.0   NaN
# 2                     NaN                5.0            NaN  8.97
# 3                 Teacher                NaN            5.0   NaN
# 4        Business Analyst                NaN            1.0   NaN
# ...                   ...                ...            ...   ...
# 140695                NaN                NaN            5.0   NaN
# 140696     Content Writer                NaN            5.0   NaN
# 140697  Marketing Manager                NaN            3.0   NaN
# 140698            Plumber                NaN            5.0   NaN
# 140699                NaN                4.0            NaN  9.24
#
#         Study Satisfaction  Job Satisfaction     Sleep Duration  \
# 0                      NaN               2.0  More than 8 hours
# 1                      NaN               3.0  Less than 5 hours
# 2                      2.0               NaN          5-6 hours
# 3                      NaN               1.0  Less than 5 hours
# 4                      NaN               1.0          5-6 hours
# ...                    ...               ...                ...
# 140695                 NaN               4.0          5-6 hours
# 140696                 NaN               4.0          7-8 hours
# 140697                 NaN               1.0  More than 8 hours
# 140698                 NaN               2.0          5-6 hours
# 140699                 1.0               NaN  Less than 5 hours
#
#        Dietary Habits    Degree Have you ever had suicidal thoughts ?  \
# 0             Healthy       BHM                                    No
# 1           Unhealthy       LLB                                   Yes
# 2             Healthy   B.Pharm                                   Yes
# 3            Moderate       BBA                                   Yes
# 4           Unhealthy       BBA                                   Yes
# ...               ...       ...                                   ...
# 140695      Unhealthy  Class 12                                    No
# 140696       Moderate    B.Tech                                   Yes
# 140697       Moderate     B.Com                                    No
# 140698       Moderate        ME                                   Yes
# 140699        Healthy       BCA                                   Yes
#
#         Work/Study Hours  Financial Stress Family History of Mental Illness  \
# 0                    1.0               2.0                               No
# 1                    7.0               3.0                               No
# 2                    3.0               1.0                               No
# 3                   10.0               1.0                              Yes
# 4                    9.0               4.0                              Yes
# ...                  ...               ...                              ...
# 140695               2.0               4.0                              Yes
# 140696               6.0               5.0                              Yes
# 140697               4.0               4.0                               No
# 140698              10.0               1.0                               No
# 140699               2.0               3.0                              Yes
#
#         Depression  Sleep Duration_missing
# 0                0                       0
# 1                1                       0
# 2                1                       0
# 3                1                       0
# 4                0                       0
# ...            ...                     ...
# 140695           1                       0
# 140696           0                       0
# 140697           0                       0
# 140698           0                       0
# 140699           1                       0
#
# [140700 rows x 19 columns]

# %%
import numpy as np
import re

def convert_sleep_to_hours(val):
    try:
        val = str(val).strip().lower()

        # 특별 처리: 'than n hours' → 'less than n hours' 간주
        if 'than' in val and 'less' not in val and 'more' not in val:
            match = re.search(r'\d+', val)
            if match:
                return float(match.group()) - 0.5

        # Less than n hours → n - 0.5
        if 'less than' in val:
            match = re.search(r'\d+', val)
            if match:
                return float(match.group()) - 0.5

        # More than n hours → n + 0.5
        elif 'more than' in val:
            match = re.search(r'\d+', val)
            if match:
                return float(match.group()) + 0.5

        # 정확히 n hours → 숫자만 추출
        elif re.match(r'^\d+\s*hours$', val):
            return float(re.findall(r'\d+', val)[0])

        # n-m hours 또는 n–n → 평균값
        elif re.search(r'\d+\s*[-–~]\s*\d+', val):
            nums = [int(n) for n in re.findall(r'\d+', val)]
            if len(nums) == 2:
                return sum(nums) / 2

        # 숫자만 → 그대로
        elif re.match(r'^\d+(\.\d+)?$', val):
            return float(val)

        # 나머지는 이상값으로 간주
        else:
            return np.nan

    except:
        return np.nan

# %%
train['Sleep Duration'] = train['Sleep Duration'].apply(convert_sleep_to_hours)

# %%
train['Sleep Duration'].value_counts()
# Out:
# Sleep Duration
# 4.5     38816
# 7.5     36969
# 8.5     32728
# 5.5     32142
# 3.5        16
# 6.5         8
# 5.0         5
# 2.5         5
# 7.0         4
# 10.5        2
# 10.0        2
# 1.5         1
# 2.0         1
# 8.0         1
# Name: count, dtype: int64

# %%
print(train['Sleep Duration'].dtype)
# Out:
# float64

# %% [markdown]
# ## 2. 결측치 처리

# %% [markdown]
# #### 2-1. 결측률 80%

# %% [markdown]
# - 파생 변수 만들어서(결측 여부) 의미 있는 누락 정보 보존 + 과적합 방지 할 것인지
# - 아니면 값을 대체할지
#
# 일단 파생 변수를 만들어 보겠음.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 필요한 컬럼만 선택하고 결측치 제거
cols = ['Academic Pressure', 'Study Satisfaction', 'CGPA', 'Depression']
subset = train[cols].dropna()

# 상관관계 히트맵 그리기
plt.figure(figsize=(8, 6))
sns.heatmap(subset.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap (after dropping missing values)")
plt.show()

# %%
# 1. CGPA 컬럼 제거
train.drop(columns=['CGPA'], inplace=True)

# %%
# 2. Academic Pressure 결측 여부 파생 변수
train['Academic_Pressure_missing'] = train['Academic Pressure'].isnull().astype(int)

# 3. Study Satisfaction 결측 여부 파생 변수
train['Study_Satisfaction_missing'] = train['Study Satisfaction'].isnull().astype(int)

# %%
# # # 2. Work Pressure 결측치 채우기
# train.loc[(train['Working Professional or Student'] == 'Student') & (train['Work Pressure'].isna()),'Work_Pressure'] = -1

# %%
train['Academic_Pressure_missing']
# Out:
# 0         1
# 1         1
# 2         0
# 3         1
# 4         1
#          ..
# 140695    1
# 140696    1
# 140697    1
# 140698    1
# 140699    0
# Name: Academic_Pressure_missing, Length: 140700, dtype: int64

# %% [markdown]
# *결과 예시*
#
# | Academic Pressure | Academic\_Pressure\_missing | Study Satisfaction | Study\_Satisfaction\_missing |
# | ----------------- | --------------------------- | ------------------ | ---------------------------- |
# | 3.0               | 0                           | 4.0                | 0                            |
# | NaN               | 1                           | NaN                | 1                            |
# | 2.0               | 0                           | NaN                | 1                            |

# %% [markdown]
# - 원래 컬럼의 nan은 어떻게 처리?
#
#     - 파생 변수를 만들었기 때문에, 그대로 두어도 됨.
#     - 결측 여부 정보를 이미 담고 있어서
#     - 하지만 사용하는 모델에 따라 nan을 허용하지 않으면 대체해야 함
#
# 1. 평균값 대체
# - 가능은 하지만 무분별한 평균 대체는 정보 손실 및 왜곡을 유발할 수 있음.
# - 특히 결측 자체가 의미를 갖는 경우(예: 설문 무응답 → 스트레스 회피?)엔 단순 평균은 부적절할 수 있음.
# -
# ```
# train['Academic Pressure'].fillna(train['Academic Pressure'].median(), inplace=True)
# train['Study Satisfaction'].fillna(train['Study Satisfaction'].median(), inplace=True)
# ```
#
# 2. imputer로 값 채우기
# - 권장되는 방식!
#
# - 파생 변수 없이 평균값 대체만 하면
#     - 결측값이 있었다는 정보를 완전히 잃어버림
#     - 실제로 결측이 의미를 가지는 경우 오히려 성능 저하

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')  # 또는 'median', 'most_frequent'
train['Academic Pressure'] = imputer.fit_transform(train[['Academic Pressure']])
train['Study Satisfaction'] = imputer.fit_transform(train[['Study Satisfaction']])

# %% [markdown]
# #### 2-2. 나머지 결측치 처리

# %%
# train = train[train['Financial Stress'].notnull()].copy()

# %%
train['Financial Stress'].value_counts()
# Out:
# Financial Stress
# 2.0    31451
# 5.0    28279
# 4.0    27765
# 1.0    27211
# 3.0    25990
# Name: count, dtype: int64

# %%
train['Financial Stress'] = train['Financial Stress'].fillna(2.0)

# %%
train['Work_Pressure_missing'] = train['Work Pressure'].isnull().astype(int)
train['Job_Satisfaction_missing'] = train['Job Satisfaction'].isnull().astype(int)

# %%
train['Work Pressure'] = imputer.fit_transform(train[['Work Pressure']])
train['Job Satisfaction'] = imputer.fit_transform(train[['Job Satisfaction']])

# %%
print(train.isnull().sum().sort_values(ascending=False).head())
# Out:
# Profession                               36630
# Dietary Habits                               4
# Degree                                       2
# Have you ever had suicidal thoughts ?        0
# Work_Pressure_missing                        0
# dtype: int64

# %% [markdown]
# #### 2-3. 범주형 결측치 처리

# %%
train['Profession'].fillna('Missing', inplace=True)
# Out:
# /var/folders/vp/r4ltbhf53594yjfl0f86yqv80000gp/T/ipykernel_88445/4215184188.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train['Profession'].fillna('Missing', inplace=True)

# %%
print(train.isnull().sum().sort_values(ascending=False).head())
# Out:
# Dietary Habits                           4
# Degree                                   2
# Have you ever had suicidal thoughts ?    0
# Work_Pressure_missing                    0
# Study_Satisfaction_missing               0
# dtype: int64

# %% [markdown]
# ### 3. 수치형 컬럼 스케일링

# %%
train.describe()
# Out:
#                  Age  Academic Pressure  Work Pressure  Study Satisfaction  \
# count  140700.000000      140700.000000  140700.000000       140700.000000
# mean       40.388621           3.142273       2.998998            2.944940
# std        12.384099           0.614679       1.258598            0.605658
# min        18.000000           1.000000       1.000000            1.000000
# 25%        29.000000           3.142273       2.000000            2.944940
# 50%        42.000000           3.142273       2.998998            2.944940
# 75%        51.000000           3.142273       4.000000            2.944940
# max        60.000000           5.000000       5.000000            5.000000
#
#        Job Satisfaction  Sleep Duration  Work/Study Hours  Financial Stress  \
# count     140700.000000   140700.000000     140700.000000     140700.000000
# mean           2.974404        6.447296          6.252679          2.988955
# std            1.267871        1.588961          3.853615          1.413623
# min            1.000000        1.500000          0.000000          1.000000
# 25%            2.000000        4.500000          3.000000          2.000000
# 50%            2.974404        5.500000          6.000000          3.000000
# 75%            4.000000        7.500000         10.000000          4.000000
# max            5.000000       10.500000         12.000000          5.000000
#
#           Depression  Sleep Duration_missing  Academic_Pressure_missing  \
# count  140700.000000           140700.000000              140700.000000
# mean        0.181713                0.000163                   0.801727
# std         0.385609                0.012784                   0.398700
# min         0.000000                0.000000                   0.000000
# 25%         0.000000                0.000000                   1.000000
# 50%         0.000000                0.000000                   1.000000
# 75%         0.000000                0.000000                   1.000000
# max         1.000000                1.000000                   1.000000
#
#        Study_Satisfaction_missing  Work_Pressure_missing  \
# count               140700.000000          140700.000000
# mean                     0.801727               0.198422
# std                      0.398700               0.398813
# min                      0.000000               0.000000
# 25%                      1.000000               0.000000
# 50%                      1.000000               0.000000
# 75%                      1.000000               0.000000
# max                      1.000000               1.000000
#
#        Job_Satisfaction_missing
# count             140700.000000
# mean                   0.198365
# std                    0.398770
# min                    0.000000
# 25%                    0.000000
# 50%                    0.000000
# 75%                    0.000000
# max                    1.000000

# %% [markdown]
# | 컬럼명                | 범위           | 평균 ± 표준편차           | 이유                               |
# | ------------------ | ------------ | ----------------- | -------------------------------- |
# | `Age`              | 18 \~ 60     | 평균40.4, std 12.4 | 넓은 범위. 다른 변수와 범위 차 큼             |
# | `Work/Study Hours` | 0 \~ 12      | 평균 6.25, std 3.85 | 0부터 시작, 12까지 존재 → 거리 기반 모델에 영향 큼 |
# | `Financial Stress` | 1 \~ 5       | 평균 2.99           | 다른 스트레스 계열들과 통일된 스케일 유리          |

# %% [markdown]
# - 범위가 넓은 수치형 변수
#     - 표준화를 적용하기

# %%
from sklearn.preprocessing import StandardScaler

scale_cols = ['Age', 'Sleep Duration', 'Work/Study Hours', 'Financial Stress']

scaler = StandardScaler()
train[scale_cols] = scaler.fit_transform(train[scale_cols])

# %%
train[scale_cols].describe()
# Out:
#                 Age  Sleep Duration  Work/Study Hours  Financial Stress
# count  1.407000e+05    1.407000e+05      1.407000e+05      1.407000e+05
# mean  -6.219143e-17   -3.181535e-17     -7.862936e-17      1.383715e-17
# std    1.000004e+00    1.000004e+00      1.000004e+00      1.000004e+00
# min   -1.807859e+00   -3.113552e+00     -1.622555e+00     -1.406997e+00
# 25%   -9.196197e-01   -1.225519e+00     -8.440624e-01     -6.995918e-01
# 50%    1.301172e-01   -5.961751e-01     -6.556970e-02      7.813129e-03
# 75%    8.568581e-01    6.625135e-01      9.724205e-01      7.152181e-01
# max    1.583599e+00    2.550546e+00      1.491416e+00      1.422623e+00

# %% [markdown]
# ### 4. 이진 범주형 -> 숫자 변환 (Yes/No → 1/0)

# %%
binary_cols = ['Have you ever had suicidal thoughts ?', 'Family History of Mental Illness']
for col in binary_cols:
    train[col] = train[col].map({'Yes': 1, 'No': 0})

# %% [markdown]
# ### (5). 범주형 확인

# %% [markdown]
# - 원핫인코딩 전, 고차원을 방지하기 위해 이상치 처리했습니다.

# %% [markdown]
# #### (5)-1. City

# %% [markdown]
# 문제점
# - 도시명 외에 사람 이름 등 잘못된 값이 포함 (Shrey, Vaanya, Ivaan, Gaurav 등)
# - 고유값 98개 → 원핫 인코딩 시 고차원 문제 발생
#
# 해결 방법
# - 상위 K개 도시 유지 + 나머지 Other로 묶기

# %%
# 상위 15개 도시만 유지
top_cities = train['City'].value_counts().nlargest(15).index
train['City'] = train['City'].where(train['City'].isin(top_cities), other='Other')

# %%
train['City'].value_counts()
# Out:
# City
# Other            60539
# Kalyan            6591
# Patna             5924
# Vasai-Virar       5765
# Kolkata           5689
# Ahmedabad         5613
# Meerut            5528
# Ludhiana          5226
# Pune              5210
# Rajkot            5207
# Visakhapatnam     5176
# Srinagar          5074
# Mumbai            4966
# Indore            4872
# Agra              4684
# Surat             4636
# Name: count, dtype: int64

# %% [markdown]
# #### (5)-2. Degree

# %% [markdown]
# 문제점
# - 고유값 115개 → 너무 많음
# - 실제 학위 외에 오타, 숫자, 이름 등이 섞여 있음 (29, Vivaan, Advait, Bhavesh, BCA, M.Tech, 등등)
#
# 해결 방법
# - 빈도 기준 상위 N개만 남기고 나머지는 'Other' 처리

# %%
train['Degree'].value_counts()
# Out:
# Degree
# Class 12    14729
# B.Ed        11691
# B.Arch       8742
# B.Com        8113
# B.Pharm      5856
#             ...
# Vivaan          1
# MTech           1
# 29              1
# LLCom           1
# Advait          1
# Name: count, Length: 115, dtype: int64

# %%
degree_group_map = {
    # 의학/보건
    'MD': 'Medical',
    'MBBS': 'Medical',
    'B.Pharm': 'Pharmacy',
    'M.Pharm': 'Pharmacy',
    'MPharm': 'Pharmacy',
    'P.Pharm': 'Pharmacy',
    'S.Pharm': 'Pharmacy',
    'N.Pharm': 'Pharmacy',

    # 공학/기술
    'B.Tech': 'Engineering',
    'M.Tech': 'Engineering',
    'ME': 'Engineering',
    'MTech': 'Engineering',
    'M_Tech': 'Engineering',
    'BE': 'Engineering',
    'BCA': 'Engineering',
    'MCA': 'Engineering',
    'E.Tech': 'Engineering',
    'S.Tech': 'Engineering',
    'LLTech': 'Engineering',
    'LLCom': 'Engineering',

    # 인문/사회/비즈니스
    'BBA': 'Business',
    'MBA': 'Business',
    'M. Business Analyst': 'Business',
    'B.Com': 'Commerce',
    'M.Com': 'Commerce',
    'P.Com': 'Commerce',
    'LLB': 'Law',
    'LLM': 'Law',
    'LLBA': 'Law',
    'LL.Com': 'Law',
    'LL B.Ed': 'Education',
    'B.Ed': 'Education',
    'M.Ed': 'Education',
    'L.Ed': 'Education',
    'K.Ed': 'Education',
    'LLEd': 'Education',
    'BEd': 'Education',

    # 과학
    'BSc': 'Science',
    'MSc': 'Science',
    'B.Sc': 'Science',

    # 기타, 건축, 호텔경영 등
    'BHM': 'Hospitality',
    'MHM': 'Hospitality',
    'B.Arch': 'Architecture',
    'M.Arch': 'Architecture',
    'BArch': 'Architecture',
    'B.B.Arch': 'Architecture',

    # 학위 및 학교 졸업
    'PhD': 'PhD',
    'Class 12': 'School',
    'Class 11': 'School',
}

train['degree_group'] =train['Degree'].apply(lambda x: degree_group_map.get(x, 'Other'))

train=train.drop('Degree',axis=1)

# %%
train['degree_group'].value_counts()
# Out:
# degree_group
# Engineering     26615
# Education       17367
# School          14730
# Commerce        11209
# Pharmacy        10397
# Science          9909
# Law              8998
# Business         8849
# Architecture     8750
# Hospitality      7591
# Other            6717
# Medical          6465
# PhD              3103
# Name: count, dtype: int64

# %% [markdown]
# #### (5)-3. Dietary Habits

# %% [markdown]
# Moderate, Unhealthy, Healthy는 명확한 카테고리
#
# 나머지는 이상값 / 오입력 / 다른 컬럼에서 잘못 섞인 값임

# %%
train['Dietary Habits'].value_counts()
# Out:
# Dietary Habits
# Moderate             49705
# Unhealthy            46227
# Healthy              44741
# Yes                      2
# No                       2
# More Healthy             2
# No Healthy               1
# Class 12                 1
# Indoor                   1
# Male                     1
# Vegas                    1
# M.Tech                   1
# Less Healthy             1
# 1.0                      1
# Electrician              1
# Hormonal                 1
# Mihir                    1
# Less than Healthy        1
# 3                        1
# Gender                   1
# BSc                      1
# Pratham                  1
# 2                        1
# Name: count, dtype: int64

# %%
# 정상 값만 남기고 나머지는 NaN으로
valid_dietary = ['Moderate', 'Unhealthy', 'Healthy']
train['Dietary Habits'] = train['Dietary Habits'].where(train['Dietary Habits'].isin(valid_dietary))

# 결측값은 최빈값으로 대체
train['Dietary Habits'] = train['Dietary Habits'].fillna(train['Dietary Habits'].mode()[0])

# %%
train['Dietary Habits'].value_counts()
# Out:
# Dietary Habits
# Moderate     49732
# Unhealthy    46227
# Healthy      44741
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# Gender, Working Status - Binary
train['Gender'] = train['Gender'].map({'Male': 1, 'Female': 0})
train['Working Professional or Student'] = train['Working Professional or Student'].map({'Working Professional': 1, 'Student': 0})

# Degree, Dietary Habits - One-hot encoding
train = pd.get_dummies(train, columns=['degree_group', 'Dietary Habits'], drop_first=True)

# Profession, City - Target encoding (또는 frequency encoding)
# 예: Target Mean Encoding (Depression 컬럼 사용)
profession_target_mean = train.groupby('Profession')['Depression'].mean()
train['Profession' + '_target'] = train['Profession'].map(profession_target_mean)
city_target_mean = train.groupby('City')['Depression'].mean()
train['City' + '_target'] = train['City'].map(city_target_mean)

# 이후 필요시 원본 컬럼 제거
train.drop(columns=['Profession', 'City'], inplace=True)

# %%
train
# Out:
#         Gender       Age  Working Professional or Student  Academic Pressure  \
# 0            0  0.695360                                1           3.142273
# 1            1 -1.161867                                1           3.142273
# 2            1 -0.596624                                0           5.000000
# 3            1 -1.484863                                1           3.142273
# 4            0 -0.838871                                1           3.142273
# ...        ...       ...                              ...                ...
# 140695       0 -1.807859                                1           3.142273
# 140696       0  0.049368                                1           3.142273
# 140697       0 -1.323365                                1           3.142273
# 140698       0  0.695360                                1           3.142273
# 140699       1 -1.081118                                0           4.000000
#
#         Work Pressure  Study Satisfaction  Job Satisfaction  Sleep Duration  \
# 0            5.000000             2.94494          2.000000        1.291858
# 1            4.000000             2.94494          3.000000       -1.225519
# 2            2.998998             2.00000          2.974404       -0.596175
# 3            5.000000             2.94494          1.000000       -1.225519
# 4            1.000000             2.94494          1.000000       -0.596175
# ...               ...                 ...               ...             ...
# 140695       5.000000             2.94494          4.000000       -0.596175
# 140696       5.000000             2.94494          4.000000        0.662513
# 140697       3.000000             2.94494          1.000000        1.291858
# 140698       5.000000             2.94494          2.000000       -0.596175
# 140699       2.998998             1.00000          2.974404       -1.225519
#
#         Have you ever had suicidal thoughts ?  Work/Study Hours  ...  \
# 0                                           0         -1.363057  ...
# 1                                           1          0.193928  ...
# 2                                           1         -0.844062  ...
# 3                                           1          0.972421  ...
# 4                                           1          0.712923  ...
# ...                                       ...               ...  ...
# 140695                                      0         -1.103560  ...
# 140696                                      1         -0.065570  ...
# 140697                                      0         -0.584565  ...
# 140698                                      1          0.972421  ...
# 140699                                      1         -1.103560  ...
#
#         degree_group_Medical  degree_group_Other  degree_group_PhD  \
# 0                      False               False             False
# 1                      False               False             False
# 2                      False               False             False
# 3                      False               False             False
# 4                      False               False             False
# ...                      ...                 ...               ...
# 140695                 False               False             False
# 140696                 False               False             False
# 140697                 False               False             False
# 140698                 False               False             False
# 140699                 False               False             False
#
#         degree_group_Pharmacy  degree_group_School  degree_group_Science  \
# 0                       False                False                 False
# 1                       False                False                 False
# 2                        True                False                 False
# 3                       False                False                 False
# 4                       False                False                 False
# ...                       ...                  ...                   ...
# 140695                  False                 True                 False
# 140696                  False                False                 False
# 140697                  False                False                 False
# 140698                  False                False                 False
# 140699                  False                False                 False
#
#         Dietary Habits_Moderate  Dietary Habits_Unhealthy  Profession_target  \
# 0                         False                     False           0.048567
# 1                         False                      True           0.055649
# 2                         False                     False           0.534944
# 3                          True                     False           0.055649
# 4                         False                      True           0.056628
# ...                         ...                       ...                ...
# 140695                    False                      True           0.534944
# 140696                     True                     False           0.018684
# 140697                     True                     False           0.050607
# 140698                     True                     False           0.064073
# 140699                    False                     False           0.534944
#
#         City_target
# 0          0.192690
# 1          0.186194
# 2          0.159196
# 3          0.131293
# 4          0.186194
# ...             ...
# 140695     0.217887
# 140696     0.186194
# 140697     0.173668
# 140698     0.211667
# 140699     0.163234
#
# [140700 rows x 34 columns]

# %%
from sklearn.model_selection import train_test_split

def get_train_test_dataset(df=None):
    train_copy = train

    y_target = train_copy['Depression']
    X_features = train_copy.drop('Depression', axis=1)

    X_train, X_test, y_train, y_test = train_test_split(X_features, y_target,
                                                        test_size=0.3, random_state=0, stratify=y_target)

    return X_train, X_test, y_train, y_test

X_train, X_test, y_train, y_test = get_train_test_dataset(train)

# %%
from sklearn.model_selection import train_test_split

def get_train_test_dataset(df=None):
    train_copy = train

    y_target = train_copy['Depression']
    X_features = train_copy.drop('Depression', axis=1)

    X_train_val, X_test, y_train_val, y_test = train_test_split(X_features, y_target, test_size=0.2, random_state=42, stratify=y_target)
    X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=42, stratify=y_train_val)

    return X_train, X_test, y_train, y_test, X_val, y_val

X_train, X_test, y_train, y_test, X_val, y_val = get_train_test_dataset(train)

# %%
# %pip install catboost optuna 

from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.metrics import classification_report, accuracy_score, f1_score
from sklearn.model_selection import cross_val_score
import optuna

# categorical columns, keep track of them:
cat_features = [] 

# params 
def objective(trial):
    params = {
        "iterations": trial.suggest_int("iterations", 500, 1000),
        "depth": trial.suggest_int("depth", 8, 10),
        "learning_rate": trial.suggest_float("learning_rate", 0.07, 0.22, log=True),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 0.2, 2.0, log=True),
        "bagging_temperature": trial.suggest_float("bagging_temperature", 0.4, 0.9),
        "border_count": trial.suggest_int("border_count", 200, 255),
        "random_strength": trial.suggest_float("random_strength", 0.01, 0.4),
    }

    model = CatBoostClassifier(**params)

    model.fit(X_train, y_train, eval_set=(X_test, y_test), cat_features=cat_features, early_stopping_rounds=30, verbose=0)

    preds = model.predict(X_test)
    accuracy = accuracy_score(y_test, preds)

    return accuracy

study = optuna.create_study(direction="maximize") 
study.optimize(objective, n_trials=50)

print("Best trial:")
print(study.best_trial)

print("Best params:")
print(study.best_params)

# Train final model
final_model = CatBoostClassifier(**study.best_params)
final_model.fit(X_train, y_train, cat_features=cat_features)

import joblib
joblib.dump(study, "catboost_optuna_study.pkl")
# Out:
# Requirement already satisfied: catboost in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (1.2.8)
# Requirement already satisfied: optuna in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (4.3.0)
# Requirement already satisfied: graphviz in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from catboost) (3.10.1)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from catboost) (2.2.3)
# Requirement already satisfied: scipy in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from catboost) (1.15.2)
# Requirement already satisfied: plotly in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from catboost) (6.1.2)
# Requirement already satisfied: six in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from catboost) (1.17.0)
# Requirement already satisfied: alembic>=1.5.0 in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from optuna) (1.16.1)
# Requirement already satisfied: colorlog in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from optuna) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: greenlet>=1 in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from matplotlib->catboost) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: pillow>=8 in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from matplotlib->catboost) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from matplotlib->catboost) (3.2.3)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from plotly->catboost) (1.41.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /Users/hb/miniconda3/envs/moduenv/lib/python3.12/site-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# [I 2025-06-03 14:46:26,518] A new study created in memory with name: no-name-00fb5a75-a78d-4a00-a857-0583f87792d8
# Note: you may need to restart the kernel to use updated packages.
# [I 2025-06-03 14:46:29,706] Trial 0 finished with value: 0.9384150675195452 and parameters: {'iterations': 769, 'depth': 10, 'learning_rate': 0.08404929927510103, 'l2_leaf_reg': 0.49914557496958717, 'bagging_temperature': 0.65627058290826, 'border_count': 221, 'random_strength': 0.04792705829336842}. Best is trial 0 with value: 0.9384150675195452.
# [I 2025-06-03 14:46:31,297] Trial 1 finished with value: 0.9383795309168443 and parameters: {'iterations': 741, 'depth': 8, 'learning_rate': 0.13443941065390336, 'l2_leaf_reg': 1.0661741694636673, 'bagging_temperature': 0.6233224511644163, 'border_count': 208, 'random_strength': 0.3225446481406777}. Best is trial 0 with value: 0.9384150675195452.
# [I 2025-06-03 14:46:33,738] Trial 2 finished with value: 0.9385572139303483 and parameters: {'iterations': 735, 'depth': 8, 'learning_rate': 0.0944755079176732, 'l2_leaf_reg': 0.2532321726948528, 'bagging_temperature': 0.8047938973231386, 'border_count': 234, 'random_strength': 0.03356449999573279}. Best is trial 2 with value: 0.9385572139303483.
# [I 2025-06-03 14:46:37,781] Trial 3 finished with value: 0.9381663113006397 and parameters: {'iterations': 652, 'depth': 10, 'learning_rate': 0.1044665137775559, 'l2_leaf_reg': 0.5977044891707624, 'bagging_temperature': 0.6909365406650687, 'border_count': 252, 'random_strength': 0.22903564429529083}. Best is trial 2 with value: 0.9385572139303483.
# [I 2025-06-03 14:46:39,537] Trial 4 finished with value: 0.9386638237384506 and parameters: {'iterations': 696, 'depth': 8, 'learning_rate': 0.20687598102446936, 'l2_leaf_reg': 0.5786669580388287, 'bagging_temperature': 0.579479017021056, 'border_count': 206, 'random_strength': 0.2910493519560829}. Best is trial 4 with value: 0.9386638237384506.
# [I 2025-06-03 14:46:43,285] Trial 5 finished with value: 0.9391613361762615 and parameters: {'iterations': 672, 'depth': 9, 'learning_rate': 0.08416063741575454, 'l2_leaf_reg': 0.4511466388833143, 'bagging_temperature': 0.5429336104204875, 'border_count': 201, 'random_strength': 0.14201486748812758}. Best is trial 5 with value: 0.9391613361762615.
# [I 2025-06-03 14:46:45,078] Trial 6 finished with value: 0.9390547263681592 and parameters: {'iterations': 524, 'depth': 8, 'learning_rate': 0.18330758746569792, 'l2_leaf_reg': 0.679416480738079, 'bagging_temperature': 0.668822859391656, 'border_count': 228, 'random_strength': 0.22743782776932905}. Best is trial 5 with value: 0.9391613361762615.
# [I 2025-06-03 14:46:47,537] Trial 7 finished with value: 0.9363894811656006 and parameters: {'iterations': 986, 'depth': 10, 'learning_rate': 0.1834711489106249, 'l2_leaf_reg': 0.5067556915517257, 'bagging_temperature': 0.47199722273388717, 'border_count': 241, 'random_strength': 0.34201048806363665}. Best is trial 5 with value: 0.9391613361762615.
# [I 2025-06-03 14:46:50,830] Trial 8 finished with value: 0.9389481165600568 and parameters: {'iterations': 732, 'depth': 10, 'learning_rate': 0.1550520912906121, 'l2_leaf_reg': 1.6226043530429424, 'bagging_temperature': 0.8963564303525224, 'border_count': 254, 'random_strength': 0.17147560082020263}. Best is trial 5 with value: 0.9391613361762615.
# [I 2025-06-03 14:46:53,941] Trial 9 finished with value: 0.9388770433546553 and parameters: {'iterations': 899, 'depth': 9, 'learning_rate': 0.12450603956067739, 'l2_leaf_reg': 1.6794142381634163, 'bagging_temperature': 0.8721838309448222, 'border_count': 238, 'random_strength': 0.07337256573186711}. Best is trial 5 with value: 0.9391613361762615.
# [I 2025-06-03 14:46:58,250] Trial 10 finished with value: 0.9388059701492537 and parameters: {'iterations': 538, 'depth': 9, 'learning_rate': 0.07681168410910175, 'l2_leaf_reg': 0.21739001245646095, 'bagging_temperature': 0.41795416763294074, 'border_count': 200, 'random_strength': 0.11774583046509925}. Best is trial 5 with value: 0.9391613361762615.
# [I 2025-06-03 14:47:00,452] Trial 11 finished with value: 0.9384861407249467 and parameters: {'iterations': 503, 'depth': 9, 'learning_rate': 0.16382456524318043, 'l2_leaf_reg': 0.350631867114434, 'bagging_temperature': 0.5266658511868334, 'border_count': 223, 'random_strength': 0.2330840049386501}. Best is trial 5 with value: 0.9391613361762615.
# [I 2025-06-03 14:47:02,892] Trial 12 finished with value: 0.9391968727789624 and parameters: {'iterations': 611, 'depth': 8, 'learning_rate': 0.10783242891606934, 'l2_leaf_reg': 0.9725408608439994, 'bagging_temperature': 0.7324480669966879, 'border_count': 216, 'random_strength': 0.15498989680143707}. Best is trial 12 with value: 0.9391968727789624.
# [I 2025-06-03 14:47:06,611] Trial 13 finished with value: 0.9389481165600568 and parameters: {'iterations': 646, 'depth': 9, 'learning_rate': 0.07035778416496144, 'l2_leaf_reg': 0.902159509599433, 'bagging_temperature': 0.7352955758834394, 'border_count': 214, 'random_strength': 0.14389886204795332}. Best is trial 12 with value: 0.9391968727789624.
# [I 2025-06-03 14:47:08,552] Trial 14 finished with value: 0.9389836531627577 and parameters: {'iterations': 602, 'depth': 8, 'learning_rate': 0.10360924259503312, 'l2_leaf_reg': 0.3515505848070947, 'bagging_temperature': 0.747854742079469, 'border_count': 214, 'random_strength': 0.11696568664090481}. Best is trial 12 with value: 0.9391968727789624.
# [I 2025-06-03 14:47:11,285] Trial 15 finished with value: 0.9393390191897655 and parameters: {'iterations': 820, 'depth': 9, 'learning_rate': 0.09116329729391687, 'l2_leaf_reg': 1.0822805444658936, 'bagging_temperature': 0.5620279205965157, 'border_count': 200, 'random_strength': 0.39027637083117583}. Best is trial 15 with value: 0.9393390191897655.
# [I 2025-06-03 14:47:14,108] Trial 16 finished with value: 0.938770433546553 and parameters: {'iterations': 838, 'depth': 8, 'learning_rate': 0.11249957844626424, 'l2_leaf_reg': 1.1509233153111458, 'bagging_temperature': 0.7928781943833312, 'border_count': 213, 'random_strength': 0.3855450195839688}. Best is trial 15 with value: 0.9393390191897655.
# [I 2025-06-03 14:47:22,201] Trial 17 finished with value: 0.9383795309168443 and parameters: {'iterations': 833, 'depth': 9, 'learning_rate': 0.09332271095775066, 'l2_leaf_reg': 0.8625649097738657, 'bagging_temperature': 0.5941072927210768, 'border_count': 220, 'random_strength': 0.38740343831554747}. Best is trial 15 with value: 0.9393390191897655.
# [I 2025-06-03 14:47:27,633] Trial 18 finished with value: 0.9383084577114428 and parameters: {'iterations': 594, 'depth': 8, 'learning_rate': 0.1327613115504701, 'l2_leaf_reg': 1.284839597490006, 'bagging_temperature': 0.49198810074833865, 'border_count': 205, 'random_strength': 0.200124828954364}. Best is trial 15 with value: 0.9393390191897655.
# [I 2025-06-03 14:47:33,007] Trial 19 finished with value: 0.9384861407249467 and parameters: {'iterations': 807, 'depth': 9, 'learning_rate': 0.11358866128451002, 'l2_leaf_reg': 1.9506465486593205, 'bagging_temperature': 0.4054931250158585, 'border_count': 228, 'random_strength': 0.27651271696819457}. Best is trial 15 with value: 0.9393390191897655.
# [I 2025-06-03 14:47:36,832] Trial 20 finished with value: 0.938272921108742 and parameters: {'iterations': 906, 'depth': 9, 'learning_rate': 0.08985532453542727, 'l2_leaf_reg': 0.8225661982314278, 'bagging_temperature': 0.706004087219768, 'border_count': 209, 'random_strength': 0.2676043574840918}. Best is trial 15 with value: 0.9393390191897655.
# [I 2025-06-03 14:47:39,384] Trial 21 finished with value: 0.9390547263681592 and parameters: {'iterations': 673, 'depth': 9, 'learning_rate': 0.07971172567336922, 'l2_leaf_reg': 0.37250552939822323, 'bagging_temperature': 0.5523132650765492, 'border_count': 201, 'random_strength': 0.1730011956648084}. Best is trial 15 with value: 0.9393390191897655.
# [I 2025-06-03 14:47:41,782] Trial 22 finished with value: 0.938592750533049 and parameters: {'iterations': 589, 'depth': 9, 'learning_rate': 0.10423306574659558, 'l2_leaf_reg': 1.3503752013043713, 'bagging_temperature': 0.6143683543952214, 'border_count': 200, 'random_strength': 0.08901460991548966}. Best is trial 15 with value: 0.9393390191897655.
# [I 2025-06-03 14:47:45,444] Trial 23 finished with value: 0.937775408670931 and parameters: {'iterations': 623, 'depth': 10, 'learning_rate': 0.08819139317191811, 'l2_leaf_reg': 0.4238354754382035, 'bagging_temperature': 0.5146056498904097, 'border_count': 211, 'random_strength': 0.1561436654856211}. Best is trial 15 with value: 0.9393390191897655.
# [I 2025-06-03 14:47:48,860] Trial 24 finished with value: 0.938770433546553 and parameters: {'iterations': 783, 'depth': 9, 'learning_rate': 0.07043365257825561, 'l2_leaf_reg': 0.7634915035818844, 'bagging_temperature': 0.47688188759443917, 'border_count': 217, 'random_strength': 0.12212850715266832}. Best is trial 15 with value: 0.9393390191897655.
# [I 2025-06-03 14:47:50,742] Trial 25 finished with value: 0.9386638237384506 and parameters: {'iterations': 691, 'depth': 8, 'learning_rate': 0.09937333482441477, 'l2_leaf_reg': 1.0440672972367806, 'bagging_temperature': 0.576733484886089, 'border_count': 205, 'random_strength': 0.18765699449154105}. Best is trial 15 with value: 0.9393390191897655.
# [I 2025-06-03 14:47:54,131] Trial 26 finished with value: 0.9383084577114428 and parameters: {'iterations': 882, 'depth': 9, 'learning_rate': 0.07894833326049154, 'l2_leaf_reg': 0.28903841558410903, 'bagging_temperature': 0.6370640153305824, 'border_count': 203, 'random_strength': 0.010270233220669861}. Best is trial 15 with value: 0.9393390191897655.
# [I 2025-06-03 14:47:57,211] Trial 27 finished with value: 0.9376687988628287 and parameters: {'iterations': 576, 'depth': 10, 'learning_rate': 0.11498479803404894, 'l2_leaf_reg': 0.7036723511869177, 'bagging_temperature': 0.5460298780897794, 'border_count': 217, 'random_strength': 0.09686429099647426}. Best is trial 15 with value: 0.9393390191897655.
# [I 2025-06-03 14:47:59,778] Trial 28 finished with value: 0.938770433546553 and parameters: {'iterations': 948, 'depth': 8, 'learning_rate': 0.08344047275824919, 'l2_leaf_reg': 0.48718858528163117, 'bagging_temperature': 0.8021001348840501, 'border_count': 209, 'random_strength': 0.13977653955812}. Best is trial 15 with value: 0.9393390191897655.
# [I 2025-06-03 14:48:02,682] Trial 29 finished with value: 0.9384150675195452 and parameters: {'iterations': 777, 'depth': 10, 'learning_rate': 0.09737647345091593, 'l2_leaf_reg': 0.9591861395035604, 'bagging_temperature': 0.6604741457303905, 'border_count': 224, 'random_strength': 0.06246237315602669}. Best is trial 15 with value: 0.9393390191897655.
# [I 2025-06-03 14:48:04,999] Trial 30 finished with value: 0.9383795309168443 and parameters: {'iterations': 704, 'depth': 9, 'learning_rate': 0.12188130709818287, 'l2_leaf_reg': 1.3508811690569946, 'bagging_temperature': 0.44497983745636277, 'border_count': 233, 'random_strength': 0.34746955409336344}. Best is trial 15 with value: 0.9393390191897655.
# [I 2025-06-03 14:48:06,798] Trial 31 finished with value: 0.938770433546553 and parameters: {'iterations': 554, 'depth': 8, 'learning_rate': 0.14708288034478492, 'l2_leaf_reg': 0.6762290203817541, 'bagging_temperature': 0.6644327175137904, 'border_count': 228, 'random_strength': 0.2540419741726355}. Best is trial 15 with value: 0.9393390191897655.
# [I 2025-06-03 14:48:07,823] Trial 32 finished with value: 0.9388770433546553 and parameters: {'iterations': 516, 'depth': 8, 'learning_rate': 0.21518837885343248, 'l2_leaf_reg': 0.4891056432961172, 'bagging_temperature': 0.7507505052572975, 'border_count': 220, 'random_strength': 0.3087816426187522}. Best is trial 15 with value: 0.9393390191897655.
# [I 2025-06-03 14:48:10,168] Trial 33 finished with value: 0.9387348969438521 and parameters: {'iterations': 552, 'depth': 8, 'learning_rate': 0.0886954815360065, 'l2_leaf_reg': 1.1459744415593203, 'bagging_temperature': 0.7094634836740573, 'border_count': 232, 'random_strength': 0.21579400315958103}. Best is trial 15 with value: 0.9393390191897655.
# [I 2025-06-03 14:48:11,353] Trial 34 finished with value: 0.9396233120113717 and parameters: {'iterations': 626, 'depth': 8, 'learning_rate': 0.18434234865711102, 'l2_leaf_reg': 0.6087258503740413, 'bagging_temperature': 0.6133479845494182, 'border_count': 240, 'random_strength': 0.3486539015187813}. Best is trial 34 with value: 0.9396233120113717.
# [I 2025-06-03 14:48:12,952] Trial 35 finished with value: 0.9379886282871357 and parameters: {'iterations': 639, 'depth': 8, 'learning_rate': 0.14022587365603417, 'l2_leaf_reg': 0.4143715085299331, 'bagging_temperature': 0.6193847630257795, 'border_count': 247, 'random_strength': 0.36248549527423807}. Best is trial 34 with value: 0.9396233120113717.
# [I 2025-06-03 14:48:14,045] Trial 36 finished with value: 0.9383439943141436 and parameters: {'iterations': 726, 'depth': 8, 'learning_rate': 0.18894254022086499, 'l2_leaf_reg': 0.5972050870851427, 'bagging_temperature': 0.5555621009260716, 'border_count': 246, 'random_strength': 0.37586914305093017}. Best is trial 34 with value: 0.9396233120113717.
# [I 2025-06-03 14:48:15,392] Trial 37 finished with value: 0.9384861407249467 and parameters: {'iterations': 621, 'depth': 8, 'learning_rate': 0.16946101580477518, 'l2_leaf_reg': 0.5631993706136287, 'bagging_temperature': 0.5995890596685794, 'border_count': 243, 'random_strength': 0.3109440850295857}. Best is trial 34 with value: 0.9396233120113717.
# [I 2025-06-03 14:48:17,640] Trial 38 finished with value: 0.9385572139303483 and parameters: {'iterations': 671, 'depth': 9, 'learning_rate': 0.08449778904902171, 'l2_leaf_reg': 0.7600006596208905, 'bagging_temperature': 0.5147668184945388, 'border_count': 238, 'random_strength': 0.35441941585929165}. Best is trial 34 with value: 0.9396233120113717.
# [I 2025-06-03 14:48:19,712] Trial 39 finished with value: 0.9384150675195452 and parameters: {'iterations': 753, 'depth': 8, 'learning_rate': 0.10972426904075945, 'l2_leaf_reg': 0.2925887998103099, 'bagging_temperature': 0.6870993358204189, 'border_count': 206, 'random_strength': 0.3303830964992849}. Best is trial 34 with value: 0.9396233120113717.
# [I 2025-06-03 14:48:22,154] Trial 40 finished with value: 0.9383439943141436 and parameters: {'iterations': 668, 'depth': 10, 'learning_rate': 0.11979925672461585, 'l2_leaf_reg': 1.013087330791396, 'bagging_temperature': 0.5737962240087695, 'border_count': 249, 'random_strength': 0.18653248107515136}. Best is trial 34 with value: 0.9396233120113717.
# [I 2025-06-03 14:48:23,506] Trial 41 finished with value: 0.9381663113006397 and parameters: {'iterations': 562, 'depth': 8, 'learning_rate': 0.19460942318472055, 'l2_leaf_reg': 0.5402231580001003, 'bagging_temperature': 0.6473979545131539, 'border_count': 236, 'random_strength': 0.24199510970456609}. Best is trial 34 with value: 0.9396233120113717.
# [I 2025-06-03 14:48:24,691] Trial 42 finished with value: 0.9383439943141436 and parameters: {'iterations': 529, 'depth': 8, 'learning_rate': 0.17623132834466945, 'l2_leaf_reg': 0.6112711212605565, 'bagging_temperature': 0.6737065911010147, 'border_count': 230, 'random_strength': 0.29567830110273063}. Best is trial 34 with value: 0.9396233120113717.
# [I 2025-06-03 14:48:25,649] Trial 43 finished with value: 0.9380952380952381 and parameters: {'iterations': 616, 'depth': 8, 'learning_rate': 0.2014525567920149, 'l2_leaf_reg': 0.4336969426840687, 'bagging_temperature': 0.8397070986528363, 'border_count': 241, 'random_strength': 0.154797042615082}. Best is trial 34 with value: 0.9396233120113717.
# [I 2025-06-03 14:48:26,874] Trial 44 finished with value: 0.9391257995735608 and parameters: {'iterations': 710, 'depth': 8, 'learning_rate': 0.1564116760743755, 'l2_leaf_reg': 0.6813866805375317, 'bagging_temperature': 0.6345839611865343, 'border_count': 224, 'random_strength': 0.39498877458747234}. Best is trial 34 with value: 0.9396233120113717.
# [I 2025-06-03 14:48:28,435] Trial 45 finished with value: 0.9383439943141436 and parameters: {'iterations': 713, 'depth': 9, 'learning_rate': 0.15979097231533435, 'l2_leaf_reg': 0.6747915035945137, 'bagging_temperature': 0.6338396171744166, 'border_count': 224, 'random_strength': 0.39944875071936514}. Best is trial 34 with value: 0.9396233120113717.
# [I 2025-06-03 14:48:30,510] Trial 46 finished with value: 0.9387348969438521 and parameters: {'iterations': 758, 'depth': 8, 'learning_rate': 0.07391893804710785, 'l2_leaf_reg': 0.7963723762435417, 'bagging_temperature': 0.6021263882068641, 'border_count': 217, 'random_strength': 0.3978683168924448}. Best is trial 34 with value: 0.9396233120113717.
# [I 2025-06-03 14:48:32,303] Trial 47 finished with value: 0.9382373845060412 and parameters: {'iterations': 650, 'depth': 9, 'learning_rate': 0.1485298950963729, 'l2_leaf_reg': 1.1593233966281566, 'bagging_temperature': 0.7775095032782522, 'border_count': 203, 'random_strength': 0.3703789621076605}. Best is trial 34 with value: 0.9396233120113717.
# [I 2025-06-03 14:48:34,200] Trial 48 finished with value: 0.938770433546553 and parameters: {'iterations': 809, 'depth': 8, 'learning_rate': 0.09357278287411787, 'l2_leaf_reg': 0.9353542316617635, 'bagging_temperature': 0.5376353737251817, 'border_count': 255, 'random_strength': 0.3305689517618252}. Best is trial 34 with value: 0.9396233120113717.
# [I 2025-06-03 14:48:36,143] Trial 49 finished with value: 0.9389481165600568 and parameters: {'iterations': 729, 'depth': 8, 'learning_rate': 0.1268631693755074, 'l2_leaf_reg': 1.607986366998902, 'bagging_temperature': 0.5733930749438084, 'border_count': 226, 'random_strength': 0.3797519767393998}. Best is trial 34 with value: 0.9396233120113717.
# Best trial:
# FrozenTrial(number=34, state=1, values=[0.9396233120113717], datetime_start=datetime.datetime(2025, 6, 3, 14, 48, 10, 170507), datetime_complete=datetime.datetime(2025, 6, 3, 14, 48, 11, 353441), params={'iterations': 626, 'depth': 8, 'learning_rate': 0.18434234865711102, 'l2_leaf_reg': 0.6087258503740413, 'bagging_temperature': 0.6133479845494182, 'border_count': 240, 'random_strength': 0.3486539015187813}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'iterations': IntDistribution(high=1000, log=False, low=500, step=1), 'depth': IntDistribution(high=10, log=False, low=8, step=1), 'learning_rate': FloatDistribution(high=0.22, log=True, low=0.07, step=None), 'l2_leaf_reg': FloatDistribution(high=2.0, log=True, low=0.2, step=None), 'bagging_temperature': FloatDistribution(high=0.9, log=False, low=0.4, step=None), 'border_count': IntDistribution(high=255, log=False, low=200, step=1), 'random_strength': FloatDistribution(high=0.4, log=False, low=0.01, step=None)}, trial_id=34, value=None)
# Best params:
# {'iterations': 626, 'depth': 8, 'learning_rate': 0.18434234865711102, 'l2_leaf_reg': 0.6087258503740413, 'bagging_temperature': 0.6133479845494182, 'border_count': 240, 'random_strength': 0.3486539015187813}
# 0:	learn: 0.4226057	total: 18.5ms	remaining: 11.5s
# 1:	learn: 0.3028846	total: 30.8ms	remaining: 9.61s
# 2:	learn: 0.2438873	total: 43.1ms	remaining: 8.94s
# 3:	learn: 0.2126828	total: 58.8ms	remaining: 9.15s
# 4:	learn: 0.1933316	total: 72.8ms	remaining: 9.04s
# 5:	learn: 0.1836603	total: 85.7ms	remaining: 8.86s
# 6:	learn: 0.1751719	total: 103ms	remaining: 9.07s
# 7:	learn: 0.1695240	total: 118ms	remaining: 9.08s
# 8:	learn: 0.1665996	total: 130ms	remaining: 8.88s
# 9:	learn: 0.1626262	total: 142ms	remaining: 8.72s
# 10:	learn: 0.1606620	total: 163ms	remaining: 9.09s
# 11:	learn: 0.1578211	total: 183ms	remaining: 9.34s
# 12:	learn: 0.1565868	total: 206ms	remaining: 9.73s
# 13:	learn: 0.1549833	total: 223ms	remaining: 9.73s
# 14:	learn: 0.1537323	total: 237ms	remaining: 9.64s
# 15:	learn: 0.1522307	total: 251ms	remaining: 9.56s
# 16:	learn: 0.1515117	total: 265ms	remaining: 9.5s
# 17:	learn: 0.1503064	total: 280ms	remaining: 9.47s
# 18:	learn: 0.1496087	total: 292ms	remaining: 9.34s
# 19:	learn: 0.1489279	total: 304ms	remaining: 9.21s
# 20:	learn: 0.1481917	total: 319ms	remaining: 9.19s
# 21:	learn: 0.1476104	total: 332ms	remaining: 9.12s
# 22:	learn: 0.1470055	total: 343ms	remaining: 9s
# 23:	learn: 0.1463570	total: 358ms	remaining: 8.98s
# 24:	learn: 0.1458712	total: 375ms	remaining: 9.01s
# 25:	learn: 0.1454722	total: 393ms	remaining: 9.06s
# 26:	learn: 0.1448823	total: 410ms	remaining: 9.1s
# 27:	learn: 0.1444374	total: 428ms	remaining: 9.14s
# 28:	learn: 0.1440682	total: 440ms	remaining: 9.07s
# 29:	learn: 0.1436026	total: 453ms	remaining: 8.99s
# 30:	learn: 0.1432235	total: 468ms	remaining: 8.98s
# 31:	learn: 0.1429411	total: 483ms	remaining: 8.97s
# 32:	learn: 0.1424546	total: 500ms	remaining: 8.98s
# 33:	learn: 0.1419004	total: 516ms	remaining: 8.99s
# 34:	learn: 0.1414752	total: 532ms	remaining: 8.99s
# 35:	learn: 0.1412483	total: 545ms	remaining: 8.93s
# 36:	learn: 0.1411075	total: 556ms	remaining: 8.85s
# 37:	learn: 0.1408819	total: 572ms	remaining: 8.86s
# 38:	learn: 0.1404889	total: 589ms	remaining: 8.87s
# 39:	learn: 0.1400733	total: 608ms	remaining: 8.9s
# 40:	learn: 0.1397026	total: 628ms	remaining: 8.96s
# 41:	learn: 0.1395392	total: 646ms	remaining: 8.98s
# 42:	learn: 0.1390498	total: 668ms	remaining: 9.05s
# 43:	learn: 0.1387917	total: 684ms	remaining: 9.05s
# 44:	learn: 0.1384416	total: 702ms	remaining: 9.07s
# 45:	learn: 0.1380277	total: 715ms	remaining: 9.02s
# 46:	learn: 0.1377036	total: 729ms	remaining: 8.99s
# 47:	learn: 0.1372216	total: 749ms	remaining: 9.02s
# 48:	learn: 0.1368274	total: 762ms	remaining: 8.97s
# 49:	learn: 0.1363184	total: 775ms	remaining: 8.93s
# 50:	learn: 0.1362099	total: 794ms	remaining: 8.95s
# 51:	learn: 0.1359138	total: 811ms	remaining: 8.95s
# 52:	learn: 0.1354595	total: 825ms	remaining: 8.92s
# 53:	learn: 0.1350565	total: 845ms	remaining: 8.95s
# 54:	learn: 0.1346932	total: 859ms	remaining: 8.92s
# 55:	learn: 0.1344832	total: 871ms	remaining: 8.86s
# 56:	learn: 0.1341816	total: 882ms	remaining: 8.81s
# 57:	learn: 0.1339122	total: 898ms	remaining: 8.79s
# 58:	learn: 0.1338121	total: 910ms	remaining: 8.75s
# 59:	learn: 0.1334522	total: 922ms	remaining: 8.7s
# 60:	learn: 0.1329794	total: 938ms	remaining: 8.69s
# 61:	learn: 0.1326370	total: 953ms	remaining: 8.67s
# 62:	learn: 0.1323500	total: 965ms	remaining: 8.62s
# 63:	learn: 0.1320873	total: 977ms	remaining: 8.58s
# 64:	learn: 0.1317636	total: 1000ms	remaining: 8.63s
# 65:	learn: 0.1313667	total: 1.01s	remaining: 8.6s
# 66:	learn: 0.1310124	total: 1.02s	remaining: 8.56s
# 67:	learn: 0.1307160	total: 1.04s	remaining: 8.54s
# 68:	learn: 0.1305169	total: 1.05s	remaining: 8.5s
# 69:	learn: 0.1302194	total: 1.06s	remaining: 8.45s
# 70:	learn: 0.1299489	total: 1.08s	remaining: 8.43s
# 71:	learn: 0.1297742	total: 1.09s	remaining: 8.41s
# 72:	learn: 0.1293803	total: 1.11s	remaining: 8.38s
# 73:	learn: 0.1289488	total: 1.12s	remaining: 8.34s
# 74:	learn: 0.1286638	total: 1.13s	remaining: 8.33s
# 75:	learn: 0.1284474	total: 1.15s	remaining: 8.3s
# 76:	learn: 0.1280644	total: 1.16s	remaining: 8.26s
# 77:	learn: 0.1277662	total: 1.17s	remaining: 8.22s
# 78:	learn: 0.1274412	total: 1.19s	remaining: 8.21s
# 79:	learn: 0.1271615	total: 1.2s	remaining: 8.2s
# 80:	learn: 0.1269066	total: 1.21s	remaining: 8.17s
# 81:	learn: 0.1267006	total: 1.23s	remaining: 8.15s
# 82:	learn: 0.1265280	total: 1.24s	remaining: 8.13s
# 83:	learn: 0.1262187	total: 1.25s	remaining: 8.09s
# 84:	learn: 0.1260030	total: 1.26s	remaining: 8.05s
# 85:	learn: 0.1255979	total: 1.28s	remaining: 8.04s
# 86:	learn: 0.1253046	total: 1.29s	remaining: 8.01s
# 87:	learn: 0.1251723	total: 1.3s	remaining: 7.98s
# 88:	learn: 0.1249782	total: 1.32s	remaining: 7.97s
# 89:	learn: 0.1248125	total: 1.34s	remaining: 7.96s
# 90:	learn: 0.1244938	total: 1.35s	remaining: 7.92s
# 91:	learn: 0.1240436	total: 1.36s	remaining: 7.89s
# 92:	learn: 0.1236664	total: 1.38s	remaining: 7.88s
# 93:	learn: 0.1233561	total: 1.39s	remaining: 7.86s
# 94:	learn: 0.1231034	total: 1.4s	remaining: 7.84s
# 95:	learn: 0.1228022	total: 1.42s	remaining: 7.84s
# 96:	learn: 0.1223791	total: 1.44s	remaining: 7.83s
# 97:	learn: 0.1220581	total: 1.45s	remaining: 7.8s
# 98:	learn: 0.1218525	total: 1.46s	remaining: 7.78s
# 99:	learn: 0.1215941	total: 1.47s	remaining: 7.75s
# 100:	learn: 0.1213321	total: 1.49s	remaining: 7.73s
# 101:	learn: 0.1210188	total: 1.5s	remaining: 7.71s
# 102:	learn: 0.1205381	total: 1.52s	remaining: 7.71s
# 103:	learn: 0.1201730	total: 1.53s	remaining: 7.68s
# 104:	learn: 0.1199478	total: 1.54s	remaining: 7.65s
# 105:	learn: 0.1197202	total: 1.55s	remaining: 7.63s
# 106:	learn: 0.1195455	total: 1.57s	remaining: 7.61s
# 107:	learn: 0.1192796	total: 1.58s	remaining: 7.58s
# 108:	learn: 0.1191056	total: 1.59s	remaining: 7.56s
# 109:	learn: 0.1187417	total: 1.61s	remaining: 7.57s
# 110:	learn: 0.1183928	total: 1.63s	remaining: 7.55s
# 111:	learn: 0.1181951	total: 1.64s	remaining: 7.54s
# 112:	learn: 0.1179581	total: 1.66s	remaining: 7.51s
# 113:	learn: 0.1177303	total: 1.67s	remaining: 7.51s
# 114:	learn: 0.1174660	total: 1.68s	remaining: 7.48s
# 115:	learn: 0.1171910	total: 1.7s	remaining: 7.46s
# 116:	learn: 0.1167610	total: 1.71s	remaining: 7.45s
# 117:	learn: 0.1165760	total: 1.73s	remaining: 7.43s
# 118:	learn: 0.1162693	total: 1.74s	remaining: 7.4s
# 119:	learn: 0.1159496	total: 1.75s	remaining: 7.38s
# 120:	learn: 0.1156187	total: 1.76s	remaining: 7.36s
# 121:	learn: 0.1154468	total: 1.77s	remaining: 7.34s
# 122:	learn: 0.1151760	total: 1.79s	remaining: 7.31s
# 123:	learn: 0.1149218	total: 1.8s	remaining: 7.3s
# 124:	learn: 0.1147108	total: 1.82s	remaining: 7.3s
# 125:	learn: 0.1143343	total: 1.83s	remaining: 7.28s
# 126:	learn: 0.1140293	total: 1.85s	remaining: 7.26s
# 127:	learn: 0.1137516	total: 1.86s	remaining: 7.24s
# 128:	learn: 0.1135949	total: 1.87s	remaining: 7.22s
# 129:	learn: 0.1132409	total: 1.89s	remaining: 7.19s
# 130:	learn: 0.1129576	total: 1.9s	remaining: 7.18s
# 131:	learn: 0.1127140	total: 1.92s	remaining: 7.17s
# 132:	learn: 0.1124229	total: 1.93s	remaining: 7.15s
# 133:	learn: 0.1122268	total: 1.94s	remaining: 7.12s
# 134:	learn: 0.1120153	total: 1.96s	remaining: 7.12s
# 135:	learn: 0.1117764	total: 1.97s	remaining: 7.11s
# 136:	learn: 0.1115111	total: 1.99s	remaining: 7.1s
# 137:	learn: 0.1112069	total: 2.01s	remaining: 7.1s
# 138:	learn: 0.1109661	total: 2.03s	remaining: 7.1s
# 139:	learn: 0.1105960	total: 2.04s	remaining: 7.09s
# 140:	learn: 0.1103832	total: 2.06s	remaining: 7.07s
# 141:	learn: 0.1101723	total: 2.08s	remaining: 7.08s
# 142:	learn: 0.1097732	total: 2.09s	remaining: 7.07s
# 143:	learn: 0.1094568	total: 2.11s	remaining: 7.06s
# 144:	learn: 0.1092566	total: 2.13s	remaining: 7.06s
# 145:	learn: 0.1090243	total: 2.15s	remaining: 7.06s
# 146:	learn: 0.1088619	total: 2.16s	remaining: 7.04s
# 147:	learn: 0.1086466	total: 2.18s	remaining: 7.04s
# 148:	learn: 0.1084426	total: 2.19s	remaining: 7.03s
# 149:	learn: 0.1082044	total: 2.21s	remaining: 7.02s
# 150:	learn: 0.1080654	total: 2.23s	remaining: 7.03s
# 151:	learn: 0.1077058	total: 2.25s	remaining: 7.01s
# 152:	learn: 0.1074798	total: 2.26s	remaining: 7s
# 153:	learn: 0.1072541	total: 2.29s	remaining: 7.01s
# 154:	learn: 0.1070903	total: 2.3s	remaining: 7s
# 155:	learn: 0.1068301	total: 2.32s	remaining: 6.99s
# 156:	learn: 0.1066555	total: 2.34s	remaining: 6.98s
# 157:	learn: 0.1063696	total: 2.35s	remaining: 6.96s
# 158:	learn: 0.1061428	total: 2.36s	remaining: 6.94s
# 159:	learn: 0.1058945	total: 2.38s	remaining: 6.92s
# 160:	learn: 0.1056337	total: 2.39s	remaining: 6.91s
# 161:	learn: 0.1053332	total: 2.4s	remaining: 6.89s
# 162:	learn: 0.1050886	total: 2.42s	remaining: 6.87s
# 163:	learn: 0.1048917	total: 2.44s	remaining: 6.87s
# 164:	learn: 0.1045985	total: 2.45s	remaining: 6.85s
# 165:	learn: 0.1043576	total: 2.46s	remaining: 6.83s
# 166:	learn: 0.1040466	total: 2.48s	remaining: 6.81s
# 167:	learn: 0.1038048	total: 2.49s	remaining: 6.79s
# 168:	learn: 0.1036011	total: 2.5s	remaining: 6.77s
# 169:	learn: 0.1033418	total: 2.52s	remaining: 6.75s
# 170:	learn: 0.1030512	total: 2.53s	remaining: 6.74s
# 171:	learn: 0.1027712	total: 2.54s	remaining: 6.72s
# 172:	learn: 0.1025674	total: 2.56s	remaining: 6.7s
# 173:	learn: 0.1024346	total: 2.57s	remaining: 6.68s
# 174:	learn: 0.1022439	total: 2.58s	remaining: 6.66s
# 175:	learn: 0.1020410	total: 2.6s	remaining: 6.64s
# 176:	learn: 0.1018897	total: 2.61s	remaining: 6.62s
# 177:	learn: 0.1016871	total: 2.63s	remaining: 6.63s
# 178:	learn: 0.1014297	total: 2.65s	remaining: 6.61s
# 179:	learn: 0.1013269	total: 2.66s	remaining: 6.59s
# 180:	learn: 0.1010049	total: 2.68s	remaining: 6.59s
# 181:	learn: 0.1007113	total: 2.69s	remaining: 6.57s
# 182:	learn: 0.1004708	total: 2.7s	remaining: 6.55s
# 183:	learn: 0.1002081	total: 2.72s	remaining: 6.53s
# 184:	learn: 0.1000681	total: 2.73s	remaining: 6.52s
# 185:	learn: 0.0998750	total: 2.75s	remaining: 6.5s
# 186:	learn: 0.0997019	total: 2.76s	remaining: 6.48s
# 187:	learn: 0.0995097	total: 2.77s	remaining: 6.46s
# 188:	learn: 0.0993264	total: 2.79s	remaining: 6.45s
# 189:	learn: 0.0990261	total: 2.8s	remaining: 6.43s
# 190:	learn: 0.0987507	total: 2.82s	remaining: 6.42s
# 191:	learn: 0.0984206	total: 2.84s	remaining: 6.42s
# 192:	learn: 0.0981462	total: 2.86s	remaining: 6.41s
# 193:	learn: 0.0978759	total: 2.88s	remaining: 6.41s
# 194:	learn: 0.0977276	total: 2.9s	remaining: 6.4s
# 195:	learn: 0.0976817	total: 2.91s	remaining: 6.39s
# 196:	learn: 0.0973059	total: 2.93s	remaining: 6.38s
# 197:	learn: 0.0970444	total: 2.95s	remaining: 6.38s
# 198:	learn: 0.0968896	total: 2.96s	remaining: 6.36s
# 199:	learn: 0.0967275	total: 2.98s	remaining: 6.35s
# 200:	learn: 0.0965714	total: 3s	remaining: 6.34s
# 201:	learn: 0.0964973	total: 3.01s	remaining: 6.33s
# 202:	learn: 0.0962083	total: 3.03s	remaining: 6.32s
# 203:	learn: 0.0959831	total: 3.05s	remaining: 6.31s
# 204:	learn: 0.0957465	total: 3.07s	remaining: 6.31s
# 205:	learn: 0.0954820	total: 3.08s	remaining: 6.29s
# 206:	learn: 0.0953743	total: 3.1s	remaining: 6.28s
# 207:	learn: 0.0952711	total: 3.12s	remaining: 6.26s
# 208:	learn: 0.0950169	total: 3.13s	remaining: 6.25s
# 209:	learn: 0.0948667	total: 3.15s	remaining: 6.24s
# 210:	learn: 0.0946351	total: 3.17s	remaining: 6.23s
# 211:	learn: 0.0943719	total: 3.18s	remaining: 6.21s
# 212:	learn: 0.0940967	total: 3.2s	remaining: 6.2s
# 213:	learn: 0.0938456	total: 3.21s	remaining: 6.19s
# 214:	learn: 0.0936567	total: 3.23s	remaining: 6.17s
# 215:	learn: 0.0934426	total: 3.25s	remaining: 6.16s
# 216:	learn: 0.0933015	total: 3.27s	remaining: 6.16s
# 217:	learn: 0.0930763	total: 3.28s	remaining: 6.14s
# 218:	learn: 0.0928498	total: 3.3s	remaining: 6.13s
# 219:	learn: 0.0926314	total: 3.32s	remaining: 6.12s
# 220:	learn: 0.0923884	total: 3.33s	remaining: 6.11s
# 221:	learn: 0.0921763	total: 3.35s	remaining: 6.09s
# 222:	learn: 0.0919063	total: 3.36s	remaining: 6.08s
# 223:	learn: 0.0917793	total: 3.38s	remaining: 6.06s
# 224:	learn: 0.0916247	total: 3.39s	remaining: 6.04s
# 225:	learn: 0.0914788	total: 3.4s	remaining: 6.03s
# 226:	learn: 0.0913155	total: 3.42s	remaining: 6.01s
# 227:	learn: 0.0912081	total: 3.43s	remaining: 5.99s
# 228:	learn: 0.0910651	total: 3.44s	remaining: 5.97s
# 229:	learn: 0.0909343	total: 3.46s	remaining: 5.96s
# 230:	learn: 0.0908004	total: 3.47s	remaining: 5.94s
# 231:	learn: 0.0905772	total: 3.49s	remaining: 5.93s
# 232:	learn: 0.0904553	total: 3.5s	remaining: 5.9s
# 233:	learn: 0.0903357	total: 3.52s	remaining: 5.89s
# 234:	learn: 0.0902234	total: 3.53s	remaining: 5.87s
# 235:	learn: 0.0899606	total: 3.54s	remaining: 5.85s
# 236:	learn: 0.0897689	total: 3.56s	remaining: 5.84s
# 237:	learn: 0.0895289	total: 3.57s	remaining: 5.82s
# 238:	learn: 0.0894078	total: 3.58s	remaining: 5.8s
# 239:	learn: 0.0892233	total: 3.59s	remaining: 5.78s
# 240:	learn: 0.0889520	total: 3.62s	remaining: 5.79s
# 241:	learn: 0.0887525	total: 3.63s	remaining: 5.77s
# 242:	learn: 0.0885836	total: 3.66s	remaining: 5.76s
# 243:	learn: 0.0883816	total: 3.67s	remaining: 5.75s
# 244:	learn: 0.0881268	total: 3.69s	remaining: 5.73s
# 245:	learn: 0.0879248	total: 3.7s	remaining: 5.72s
# 246:	learn: 0.0876680	total: 3.72s	remaining: 5.71s
# 247:	learn: 0.0874140	total: 3.73s	remaining: 5.69s
# 248:	learn: 0.0872697	total: 3.75s	remaining: 5.68s
# 249:	learn: 0.0871535	total: 3.76s	remaining: 5.66s
# 250:	learn: 0.0869748	total: 3.78s	remaining: 5.64s
# 251:	learn: 0.0868247	total: 3.79s	remaining: 5.63s
# 252:	learn: 0.0866910	total: 3.8s	remaining: 5.61s
# 253:	learn: 0.0865870	total: 3.82s	remaining: 5.59s
# 254:	learn: 0.0863777	total: 3.83s	remaining: 5.58s
# 255:	learn: 0.0861217	total: 3.85s	remaining: 5.56s
# 256:	learn: 0.0859150	total: 3.86s	remaining: 5.54s
# 257:	learn: 0.0857787	total: 3.87s	remaining: 5.52s
# 258:	learn: 0.0855614	total: 3.88s	remaining: 5.5s
# 259:	learn: 0.0854704	total: 3.9s	remaining: 5.49s
# 260:	learn: 0.0853441	total: 3.91s	remaining: 5.47s
# 261:	learn: 0.0852482	total: 3.93s	remaining: 5.46s
# 262:	learn: 0.0851758	total: 3.94s	remaining: 5.44s
# 263:	learn: 0.0850666	total: 3.96s	remaining: 5.42s
# 264:	learn: 0.0848796	total: 3.97s	remaining: 5.41s
# 265:	learn: 0.0846743	total: 3.98s	remaining: 5.39s
# 266:	learn: 0.0844612	total: 3.99s	remaining: 5.37s
# 267:	learn: 0.0843257	total: 4.01s	remaining: 5.35s
# 268:	learn: 0.0841539	total: 4.02s	remaining: 5.34s
# 269:	learn: 0.0840004	total: 4.03s	remaining: 5.32s
# 270:	learn: 0.0837766	total: 4.04s	remaining: 5.3s
# 271:	learn: 0.0836051	total: 4.06s	remaining: 5.28s
# 272:	learn: 0.0834503	total: 4.07s	remaining: 5.27s
# 273:	learn: 0.0832932	total: 4.08s	remaining: 5.25s
# 274:	learn: 0.0831899	total: 4.1s	remaining: 5.23s
# 275:	learn: 0.0830640	total: 4.12s	remaining: 5.22s
# 276:	learn: 0.0828565	total: 4.13s	remaining: 5.2s
# 277:	learn: 0.0826450	total: 4.14s	remaining: 5.18s
# 278:	learn: 0.0825347	total: 4.16s	remaining: 5.17s
# 279:	learn: 0.0823142	total: 4.17s	remaining: 5.15s
# 280:	learn: 0.0820875	total: 4.18s	remaining: 5.13s
# 281:	learn: 0.0818695	total: 4.19s	remaining: 5.11s
# 282:	learn: 0.0817211	total: 4.21s	remaining: 5.1s
# 283:	learn: 0.0815470	total: 4.22s	remaining: 5.08s
# 284:	learn: 0.0813837	total: 4.23s	remaining: 5.07s
# 285:	learn: 0.0812198	total: 4.25s	remaining: 5.05s
# 286:	learn: 0.0810100	total: 4.26s	remaining: 5.03s
# 287:	learn: 0.0808604	total: 4.27s	remaining: 5.01s
# 288:	learn: 0.0807205	total: 4.28s	remaining: 5s
# 289:	learn: 0.0805735	total: 4.3s	remaining: 4.99s
# 290:	learn: 0.0804570	total: 4.32s	remaining: 4.97s
# 291:	learn: 0.0802991	total: 4.33s	remaining: 4.96s
# 292:	learn: 0.0800946	total: 4.34s	remaining: 4.94s
# 293:	learn: 0.0799896	total: 4.36s	remaining: 4.92s
# 294:	learn: 0.0798181	total: 4.37s	remaining: 4.91s
# 295:	learn: 0.0796535	total: 4.38s	remaining: 4.89s
# 296:	learn: 0.0794360	total: 4.4s	remaining: 4.88s
# 297:	learn: 0.0793886	total: 4.42s	remaining: 4.86s
# 298:	learn: 0.0792622	total: 4.43s	remaining: 4.84s
# 299:	learn: 0.0791978	total: 4.44s	remaining: 4.83s
# 300:	learn: 0.0790967	total: 4.46s	remaining: 4.81s
# 301:	learn: 0.0789371	total: 4.47s	remaining: 4.79s
# 302:	learn: 0.0788124	total: 4.48s	remaining: 4.78s
# 303:	learn: 0.0786477	total: 4.5s	remaining: 4.76s
# 304:	learn: 0.0784591	total: 4.52s	remaining: 4.75s
# 305:	learn: 0.0782888	total: 4.53s	remaining: 4.74s
# 306:	learn: 0.0781897	total: 4.54s	remaining: 4.72s
# 307:	learn: 0.0780138	total: 4.56s	remaining: 4.71s
# 308:	learn: 0.0778129	total: 4.57s	remaining: 4.69s
# 309:	learn: 0.0775707	total: 4.58s	remaining: 4.67s
# 310:	learn: 0.0774636	total: 4.6s	remaining: 4.66s
# 311:	learn: 0.0773089	total: 4.62s	remaining: 4.64s
# 312:	learn: 0.0771112	total: 4.63s	remaining: 4.63s
# 313:	learn: 0.0769683	total: 4.64s	remaining: 4.61s
# 314:	learn: 0.0768237	total: 4.65s	remaining: 4.59s
# 315:	learn: 0.0766830	total: 4.67s	remaining: 4.58s
# 316:	learn: 0.0765231	total: 4.68s	remaining: 4.56s
# 317:	learn: 0.0763767	total: 4.69s	remaining: 4.54s
# 318:	learn: 0.0762346	total: 4.71s	remaining: 4.53s
# 319:	learn: 0.0760906	total: 4.72s	remaining: 4.52s
# 320:	learn: 0.0759447	total: 4.74s	remaining: 4.5s
# 321:	learn: 0.0757195	total: 4.75s	remaining: 4.48s
# 322:	learn: 0.0757089	total: 4.76s	remaining: 4.46s
# 323:	learn: 0.0754682	total: 4.77s	remaining: 4.45s
# 324:	learn: 0.0752778	total: 4.78s	remaining: 4.43s
# 325:	learn: 0.0751628	total: 4.79s	remaining: 4.41s
# 326:	learn: 0.0748906	total: 4.81s	remaining: 4.4s
# 327:	learn: 0.0747413	total: 4.82s	remaining: 4.38s
# 328:	learn: 0.0746100	total: 4.83s	remaining: 4.37s
# 329:	learn: 0.0744909	total: 4.85s	remaining: 4.35s
# 330:	learn: 0.0742837	total: 4.86s	remaining: 4.33s
# 331:	learn: 0.0741625	total: 4.87s	remaining: 4.32s
# 332:	learn: 0.0739755	total: 4.89s	remaining: 4.3s
# 333:	learn: 0.0738311	total: 4.9s	remaining: 4.29s
# 334:	learn: 0.0736674	total: 4.92s	remaining: 4.27s
# 335:	learn: 0.0734788	total: 4.93s	remaining: 4.26s
# 336:	learn: 0.0733029	total: 4.95s	remaining: 4.24s
# 337:	learn: 0.0731837	total: 4.96s	remaining: 4.23s
# 338:	learn: 0.0730749	total: 4.97s	remaining: 4.21s
# 339:	learn: 0.0729675	total: 4.99s	remaining: 4.19s
# 340:	learn: 0.0728114	total: 5s	remaining: 4.18s
# 341:	learn: 0.0726238	total: 5.01s	remaining: 4.17s
# 342:	learn: 0.0725093	total: 5.03s	remaining: 4.15s
# 343:	learn: 0.0723982	total: 5.04s	remaining: 4.13s
# 344:	learn: 0.0722779	total: 5.05s	remaining: 4.12s
# 345:	learn: 0.0721026	total: 5.07s	remaining: 4.1s
# 346:	learn: 0.0719624	total: 5.08s	remaining: 4.08s
# 347:	learn: 0.0718190	total: 5.09s	remaining: 4.07s
# 348:	learn: 0.0716562	total: 5.11s	remaining: 4.06s
# 349:	learn: 0.0714862	total: 5.13s	remaining: 4.04s
# 350:	learn: 0.0713622	total: 5.14s	remaining: 4.03s
# 351:	learn: 0.0712010	total: 5.16s	remaining: 4.01s
# 352:	learn: 0.0710807	total: 5.17s	remaining: 4s
# 353:	learn: 0.0710093	total: 5.18s	remaining: 3.98s
# 354:	learn: 0.0708837	total: 5.19s	remaining: 3.96s
# 355:	learn: 0.0707628	total: 5.21s	remaining: 3.95s
# 356:	learn: 0.0706789	total: 5.22s	remaining: 3.93s
# 357:	learn: 0.0705444	total: 5.23s	remaining: 3.92s
# 358:	learn: 0.0703985	total: 5.24s	remaining: 3.9s
# 359:	learn: 0.0702491	total: 5.26s	remaining: 3.88s
# 360:	learn: 0.0700568	total: 5.27s	remaining: 3.87s
# 361:	learn: 0.0699209	total: 5.29s	remaining: 3.86s
# 362:	learn: 0.0698083	total: 5.3s	remaining: 3.84s
# 363:	learn: 0.0696055	total: 5.32s	remaining: 3.83s
# 364:	learn: 0.0696026	total: 5.33s	remaining: 3.81s
# 365:	learn: 0.0695028	total: 5.34s	remaining: 3.79s
# 366:	learn: 0.0694207	total: 5.35s	remaining: 3.78s
# 367:	learn: 0.0693266	total: 5.37s	remaining: 3.76s
# 368:	learn: 0.0691872	total: 5.38s	remaining: 3.75s
# 369:	learn: 0.0690213	total: 5.39s	remaining: 3.73s
# 370:	learn: 0.0688988	total: 5.41s	remaining: 3.72s
# 371:	learn: 0.0688979	total: 5.42s	remaining: 3.7s
# 372:	learn: 0.0687666	total: 5.43s	remaining: 3.68s
# 373:	learn: 0.0686431	total: 5.44s	remaining: 3.67s
# 374:	learn: 0.0685802	total: 5.46s	remaining: 3.65s
# 375:	learn: 0.0683874	total: 5.47s	remaining: 3.64s
# 376:	learn: 0.0683155	total: 5.48s	remaining: 3.62s
# 377:	learn: 0.0681770	total: 5.5s	remaining: 3.61s
# 378:	learn: 0.0680474	total: 5.51s	remaining: 3.59s
# 379:	learn: 0.0679130	total: 5.53s	remaining: 3.58s
# 380:	learn: 0.0677615	total: 5.54s	remaining: 3.56s
# 381:	learn: 0.0676647	total: 5.56s	remaining: 3.55s
# 382:	learn: 0.0675267	total: 5.58s	remaining: 3.54s
# 383:	learn: 0.0674753	total: 5.59s	remaining: 3.52s
# 384:	learn: 0.0674134	total: 5.6s	remaining: 3.51s
# 385:	learn: 0.0673470	total: 5.62s	remaining: 3.49s
# 386:	learn: 0.0672395	total: 5.63s	remaining: 3.48s
# 387:	learn: 0.0670936	total: 5.64s	remaining: 3.46s
# 388:	learn: 0.0669158	total: 5.66s	remaining: 3.45s
# 389:	learn: 0.0668016	total: 5.67s	remaining: 3.43s
# 390:	learn: 0.0666743	total: 5.68s	remaining: 3.41s
# 391:	learn: 0.0665422	total: 5.69s	remaining: 3.4s
# 392:	learn: 0.0663489	total: 5.71s	remaining: 3.38s
# 393:	learn: 0.0661792	total: 5.72s	remaining: 3.37s
# 394:	learn: 0.0660917	total: 5.74s	remaining: 3.35s
# 395:	learn: 0.0660282	total: 5.75s	remaining: 3.34s
# 396:	learn: 0.0658992	total: 5.76s	remaining: 3.32s
# 397:	learn: 0.0657794	total: 5.78s	remaining: 3.31s
# 398:	learn: 0.0656833	total: 5.79s	remaining: 3.29s
# 399:	learn: 0.0655505	total: 5.8s	remaining: 3.28s
# 400:	learn: 0.0653689	total: 5.82s	remaining: 3.26s
# 401:	learn: 0.0653076	total: 5.83s	remaining: 3.25s
# 402:	learn: 0.0651272	total: 5.84s	remaining: 3.23s
# 403:	learn: 0.0650121	total: 5.86s	remaining: 3.22s
# 404:	learn: 0.0648967	total: 5.87s	remaining: 3.2s
# 405:	learn: 0.0647572	total: 5.88s	remaining: 3.19s
# 406:	learn: 0.0646725	total: 5.89s	remaining: 3.17s
# 407:	learn: 0.0645708	total: 5.91s	remaining: 3.16s
# 408:	learn: 0.0644727	total: 5.92s	remaining: 3.14s
# 409:	learn: 0.0643110	total: 5.94s	remaining: 3.13s
# 410:	learn: 0.0642208	total: 5.95s	remaining: 3.11s
# 411:	learn: 0.0640776	total: 5.96s	remaining: 3.1s
# 412:	learn: 0.0639916	total: 5.98s	remaining: 3.08s
# 413:	learn: 0.0638644	total: 5.99s	remaining: 3.07s
# 414:	learn: 0.0637643	total: 6s	remaining: 3.05s
# 415:	learn: 0.0636218	total: 6.02s	remaining: 3.04s
# 416:	learn: 0.0635112	total: 6.03s	remaining: 3.02s
# 417:	learn: 0.0634149	total: 6.04s	remaining: 3.01s
# 418:	learn: 0.0633043	total: 6.05s	remaining: 2.99s
# 419:	learn: 0.0632175	total: 6.07s	remaining: 2.98s
# 420:	learn: 0.0630726	total: 6.08s	remaining: 2.96s
# 421:	learn: 0.0629887	total: 6.09s	remaining: 2.94s
# 422:	learn: 0.0629037	total: 6.11s	remaining: 2.93s
# 423:	learn: 0.0627655	total: 6.12s	remaining: 2.92s
# 424:	learn: 0.0625765	total: 6.13s	remaining: 2.9s
# 425:	learn: 0.0624242	total: 6.15s	remaining: 2.89s
# 426:	learn: 0.0623418	total: 6.16s	remaining: 2.87s
# 427:	learn: 0.0621994	total: 6.18s	remaining: 2.86s
# 428:	learn: 0.0620373	total: 6.19s	remaining: 2.84s
# 429:	learn: 0.0619791	total: 6.21s	remaining: 2.83s
# 430:	learn: 0.0618528	total: 6.22s	remaining: 2.81s
# 431:	learn: 0.0617428	total: 6.23s	remaining: 2.8s
# 432:	learn: 0.0616761	total: 6.25s	remaining: 2.78s
# 433:	learn: 0.0615710	total: 6.26s	remaining: 2.77s
# 434:	learn: 0.0614288	total: 6.27s	remaining: 2.75s
# 435:	learn: 0.0612705	total: 6.28s	remaining: 2.74s
# 436:	learn: 0.0611206	total: 6.3s	remaining: 2.72s
# 437:	learn: 0.0610142	total: 6.31s	remaining: 2.71s
# 438:	learn: 0.0609623	total: 6.32s	remaining: 2.69s
# 439:	learn: 0.0608033	total: 6.34s	remaining: 2.68s
# 440:	learn: 0.0606486	total: 6.36s	remaining: 2.67s
# 441:	learn: 0.0605016	total: 6.37s	remaining: 2.65s
# 442:	learn: 0.0603766	total: 6.38s	remaining: 2.64s
# 443:	learn: 0.0602330	total: 6.4s	remaining: 2.62s
# 444:	learn: 0.0601355	total: 6.41s	remaining: 2.61s
# 445:	learn: 0.0600579	total: 6.42s	remaining: 2.59s
# 446:	learn: 0.0599775	total: 6.43s	remaining: 2.58s
# 447:	learn: 0.0597981	total: 6.45s	remaining: 2.56s
# 448:	learn: 0.0597020	total: 6.46s	remaining: 2.55s
# 449:	learn: 0.0595815	total: 6.48s	remaining: 2.53s
# 450:	learn: 0.0594559	total: 6.49s	remaining: 2.52s
# 451:	learn: 0.0593501	total: 6.5s	remaining: 2.5s
# 452:	learn: 0.0591908	total: 6.52s	remaining: 2.49s
# 453:	learn: 0.0590571	total: 6.53s	remaining: 2.47s
# 454:	learn: 0.0589892	total: 6.59s	remaining: 2.48s
# 455:	learn: 0.0589174	total: 6.63s	remaining: 2.47s
# 456:	learn: 0.0588163	total: 6.69s	remaining: 2.47s
# 457:	learn: 0.0586922	total: 6.72s	remaining: 2.46s
# 458:	learn: 0.0585798	total: 6.73s	remaining: 2.45s
# 459:	learn: 0.0585169	total: 6.75s	remaining: 2.43s
# 460:	learn: 0.0583793	total: 6.76s	remaining: 2.42s
# 461:	learn: 0.0582072	total: 6.78s	remaining: 2.41s
# 462:	learn: 0.0581188	total: 6.79s	remaining: 2.39s
# 463:	learn: 0.0580397	total: 6.81s	remaining: 2.38s
# 464:	learn: 0.0578978	total: 6.82s	remaining: 2.36s
# 465:	learn: 0.0577529	total: 6.83s	remaining: 2.35s
# 466:	learn: 0.0576874	total: 6.85s	remaining: 2.33s
# 467:	learn: 0.0576100	total: 6.86s	remaining: 2.32s
# 468:	learn: 0.0575079	total: 6.87s	remaining: 2.3s
# 469:	learn: 0.0574278	total: 6.88s	remaining: 2.29s
# 470:	learn: 0.0572459	total: 6.9s	remaining: 2.27s
# 471:	learn: 0.0571354	total: 6.91s	remaining: 2.25s
# 472:	learn: 0.0570562	total: 6.92s	remaining: 2.24s
# 473:	learn: 0.0569711	total: 6.93s	remaining: 2.22s
# 474:	learn: 0.0568778	total: 6.95s	remaining: 2.21s
# 475:	learn: 0.0567862	total: 6.97s	remaining: 2.19s
# 476:	learn: 0.0566785	total: 6.98s	remaining: 2.18s
# 477:	learn: 0.0565609	total: 7s	remaining: 2.17s
# 478:	learn: 0.0564618	total: 7.01s	remaining: 2.15s
# 479:	learn: 0.0563994	total: 7.02s	remaining: 2.13s
# 480:	learn: 0.0562717	total: 7.04s	remaining: 2.12s
# 481:	learn: 0.0561478	total: 7.05s	remaining: 2.11s
# 482:	learn: 0.0560369	total: 7.06s	remaining: 2.09s
# 483:	learn: 0.0559484	total: 7.07s	remaining: 2.08s
# 484:	learn: 0.0557867	total: 7.09s	remaining: 2.06s
# 485:	learn: 0.0557230	total: 7.1s	remaining: 2.05s
# 486:	learn: 0.0556442	total: 7.11s	remaining: 2.03s
# 487:	learn: 0.0555967	total: 7.13s	remaining: 2.01s
# 488:	learn: 0.0555083	total: 7.14s	remaining: 2s
# 489:	learn: 0.0554390	total: 7.16s	remaining: 1.99s
# 490:	learn: 0.0553157	total: 7.17s	remaining: 1.97s
# 491:	learn: 0.0551790	total: 7.19s	remaining: 1.96s
# 492:	learn: 0.0550085	total: 7.2s	remaining: 1.94s
# 493:	learn: 0.0548864	total: 7.21s	remaining: 1.93s
# 494:	learn: 0.0547775	total: 7.23s	remaining: 1.91s
# 495:	learn: 0.0546827	total: 7.24s	remaining: 1.9s
# 496:	learn: 0.0546241	total: 7.25s	remaining: 1.88s
# 497:	learn: 0.0545025	total: 7.27s	remaining: 1.87s
# 498:	learn: 0.0543302	total: 7.29s	remaining: 1.85s
# 499:	learn: 0.0541971	total: 7.3s	remaining: 1.84s
# 500:	learn: 0.0541173	total: 7.31s	remaining: 1.82s
# 501:	learn: 0.0540315	total: 7.32s	remaining: 1.81s
# 502:	learn: 0.0539106	total: 7.34s	remaining: 1.79s
# 503:	learn: 0.0538033	total: 7.35s	remaining: 1.78s
# 504:	learn: 0.0536961	total: 7.36s	remaining: 1.76s
# 505:	learn: 0.0536176	total: 7.38s	remaining: 1.75s
# 506:	learn: 0.0534784	total: 7.39s	remaining: 1.74s
# 507:	learn: 0.0533386	total: 7.41s	remaining: 1.72s
# 508:	learn: 0.0532608	total: 7.42s	remaining: 1.71s
# 509:	learn: 0.0531279	total: 7.43s	remaining: 1.69s
# 510:	learn: 0.0530205	total: 7.45s	remaining: 1.68s
# 511:	learn: 0.0529014	total: 7.46s	remaining: 1.66s
# 512:	learn: 0.0528594	total: 7.47s	remaining: 1.65s
# 513:	learn: 0.0527600	total: 7.49s	remaining: 1.63s
# 514:	learn: 0.0527003	total: 7.5s	remaining: 1.62s
# 515:	learn: 0.0526596	total: 7.51s	remaining: 1.6s
# 516:	learn: 0.0525750	total: 7.53s	remaining: 1.59s
# 517:	learn: 0.0524796	total: 7.55s	remaining: 1.57s
# 518:	learn: 0.0523572	total: 7.56s	remaining: 1.56s
# 519:	learn: 0.0522664	total: 7.58s	remaining: 1.54s
# 520:	learn: 0.0521976	total: 7.59s	remaining: 1.53s
# 521:	learn: 0.0520933	total: 7.61s	remaining: 1.51s
# 522:	learn: 0.0520172	total: 7.62s	remaining: 1.5s
# 523:	learn: 0.0519160	total: 7.63s	remaining: 1.49s
# 524:	learn: 0.0518030	total: 7.64s	remaining: 1.47s
# 525:	learn: 0.0516739	total: 7.66s	remaining: 1.46s
# 526:	learn: 0.0515354	total: 7.67s	remaining: 1.44s
# 527:	learn: 0.0514545	total: 7.69s	remaining: 1.43s
# 528:	learn: 0.0513695	total: 7.7s	remaining: 1.41s
# 529:	learn: 0.0512993	total: 7.71s	remaining: 1.4s
# 530:	learn: 0.0511648	total: 7.73s	remaining: 1.38s
# 531:	learn: 0.0510480	total: 7.74s	remaining: 1.37s
# 532:	learn: 0.0509071	total: 7.75s	remaining: 1.35s
# 533:	learn: 0.0508112	total: 7.77s	remaining: 1.34s
# 534:	learn: 0.0507042	total: 7.79s	remaining: 1.32s
# 535:	learn: 0.0506012	total: 7.8s	remaining: 1.31s
# 536:	learn: 0.0504706	total: 7.82s	remaining: 1.3s
# 537:	learn: 0.0503603	total: 7.84s	remaining: 1.28s
# 538:	learn: 0.0502202	total: 7.85s	remaining: 1.27s
# 539:	learn: 0.0501170	total: 7.86s	remaining: 1.25s
# 540:	learn: 0.0500025	total: 7.88s	remaining: 1.24s
# 541:	learn: 0.0499144	total: 7.89s	remaining: 1.22s
# 542:	learn: 0.0498184	total: 7.91s	remaining: 1.21s
# 543:	learn: 0.0497560	total: 7.92s	remaining: 1.19s
# 544:	learn: 0.0496514	total: 7.93s	remaining: 1.18s
# 545:	learn: 0.0495289	total: 7.95s	remaining: 1.16s
# 546:	learn: 0.0494398	total: 7.96s	remaining: 1.15s
# 547:	learn: 0.0493221	total: 7.98s	remaining: 1.14s
# 548:	learn: 0.0492281	total: 7.99s	remaining: 1.12s
# 549:	learn: 0.0490693	total: 8s	remaining: 1.11s
# 550:	learn: 0.0489801	total: 8.02s	remaining: 1.09s
# 551:	learn: 0.0488886	total: 8.03s	remaining: 1.08s
# 552:	learn: 0.0487880	total: 8.05s	remaining: 1.06s
# 553:	learn: 0.0486862	total: 8.06s	remaining: 1.05s
# 554:	learn: 0.0485722	total: 8.08s	remaining: 1.03s
# 555:	learn: 0.0484402	total: 8.09s	remaining: 1.02s
# 556:	learn: 0.0483718	total: 8.1s	remaining: 1s
# 557:	learn: 0.0482860	total: 8.12s	remaining: 989ms
# 558:	learn: 0.0482286	total: 8.13s	remaining: 975ms
# 559:	learn: 0.0481248	total: 8.15s	remaining: 960ms
# 560:	learn: 0.0480625	total: 8.16s	remaining: 946ms
# 561:	learn: 0.0480184	total: 8.18s	remaining: 931ms
# 562:	learn: 0.0478896	total: 8.19s	remaining: 917ms
# 563:	learn: 0.0477960	total: 8.21s	remaining: 902ms
# 564:	learn: 0.0477102	total: 8.22s	remaining: 888ms
# 565:	learn: 0.0476383	total: 8.23s	remaining: 873ms
# 566:	learn: 0.0475285	total: 8.25s	remaining: 858ms
# 567:	learn: 0.0474466	total: 8.26s	remaining: 844ms
# 568:	learn: 0.0473464	total: 8.28s	remaining: 829ms
# 569:	learn: 0.0472681	total: 8.29s	remaining: 815ms
# 570:	learn: 0.0472285	total: 8.31s	remaining: 800ms
# 571:	learn: 0.0471630	total: 8.32s	remaining: 785ms
# 572:	learn: 0.0470745	total: 8.34s	remaining: 771ms
# 573:	learn: 0.0469939	total: 8.35s	remaining: 757ms
# 574:	learn: 0.0469606	total: 8.37s	remaining: 742ms
# 575:	learn: 0.0468667	total: 8.38s	remaining: 728ms
# 576:	learn: 0.0468246	total: 8.4s	remaining: 713ms
# 577:	learn: 0.0467641	total: 8.41s	remaining: 699ms
# 578:	learn: 0.0466992	total: 8.43s	remaining: 684ms
# 579:	learn: 0.0466349	total: 8.44s	remaining: 670ms
# 580:	learn: 0.0465716	total: 8.46s	remaining: 655ms
# 581:	learn: 0.0464505	total: 8.47s	remaining: 640ms
# 582:	learn: 0.0464079	total: 8.48s	remaining: 626ms
# 583:	learn: 0.0462691	total: 8.5s	remaining: 611ms
# 584:	learn: 0.0461843	total: 8.51s	remaining: 597ms
# 585:	learn: 0.0460793	total: 8.53s	remaining: 582ms
# 586:	learn: 0.0459640	total: 8.54s	remaining: 568ms
# 587:	learn: 0.0458760	total: 8.56s	remaining: 553ms
# 588:	learn: 0.0458084	total: 8.57s	remaining: 539ms
# 589:	learn: 0.0457233	total: 8.59s	remaining: 524ms
# 590:	learn: 0.0455797	total: 8.61s	remaining: 510ms
# 591:	learn: 0.0455063	total: 8.63s	remaining: 495ms
# 592:	learn: 0.0454241	total: 8.64s	remaining: 481ms
# 593:	learn: 0.0453011	total: 8.65s	remaining: 466ms
# 594:	learn: 0.0451851	total: 8.67s	remaining: 452ms
# 595:	learn: 0.0450881	total: 8.68s	remaining: 437ms
# 596:	learn: 0.0450065	total: 8.69s	remaining: 422ms
# 597:	learn: 0.0449307	total: 8.71s	remaining: 408ms
# 598:	learn: 0.0448844	total: 8.72s	remaining: 393ms
# 599:	learn: 0.0448110	total: 8.73s	remaining: 378ms
# 600:	learn: 0.0447415	total: 8.74s	remaining: 364ms
# 601:	learn: 0.0446824	total: 8.76s	remaining: 349ms
# 602:	learn: 0.0445975	total: 8.77s	remaining: 335ms
# 603:	learn: 0.0445557	total: 8.79s	remaining: 320ms
# 604:	learn: 0.0444448	total: 8.8s	remaining: 306ms
# 605:	learn: 0.0443562	total: 8.82s	remaining: 291ms
# 606:	learn: 0.0442983	total: 8.83s	remaining: 276ms
# 607:	learn: 0.0442102	total: 8.84s	remaining: 262ms
# 608:	learn: 0.0440993	total: 8.86s	remaining: 247ms
# 609:	learn: 0.0440163	total: 8.87s	remaining: 233ms
# 610:	learn: 0.0439416	total: 8.88s	remaining: 218ms
# 611:	learn: 0.0438364	total: 8.89s	remaining: 203ms
# 612:	learn: 0.0437294	total: 8.91s	remaining: 189ms
# 613:	learn: 0.0436321	total: 8.92s	remaining: 174ms
# 614:	learn: 0.0435697	total: 8.93s	remaining: 160ms
# 615:	learn: 0.0434216	total: 8.95s	remaining: 145ms
# 616:	learn: 0.0433619	total: 8.96s	remaining: 131ms
# 617:	learn: 0.0432906	total: 8.97s	remaining: 116ms
# 618:	learn: 0.0431981	total: 8.99s	remaining: 102ms
# 619:	learn: 0.0431352	total: 9s	remaining: 87.1ms
# 620:	learn: 0.0430244	total: 9.02s	remaining: 72.6ms
# 621:	learn: 0.0429722	total: 9.03s	remaining: 58.1ms
# 622:	learn: 0.0429113	total: 9.04s	remaining: 43.6ms
# 623:	learn: 0.0428312	total: 9.06s	remaining: 29ms
# 624:	learn: 0.0427347	total: 9.07s	remaining: 14.5ms
# 625:	learn: 0.0426961	total: 9.08s	remaining: 0us
# ['catboost_optuna_study.pkl']

# %%
# get the report of the model performance on accuracy and f1 and recall scores
y_pred = final_model.predict(X_test)
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Accuracy:", accuracy_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred, average='weighted'))
print ("Recall Score:", f1_score(y_test, y_pred, average='macro'))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96     23027
#            1       0.83      0.80      0.81      5113
#
#     accuracy                           0.93     28140
#    macro avg       0.89      0.88      0.89     28140
# weighted avg       0.93      0.93      0.93     28140
#
# Accuracy: 0.9328358208955224
# F1 Score: 0.9323433979062895
# Recall Score: 0.8854217732833217

# %%
import matplotlib.pyplot as plt

importances = final_model.feature_importances_
feature_names = X_train.columns

# 중요도 DataFrame 생성
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# 상위 N개 확인
print(importance_df.head(10))

# 시각화 (선택)
importance_df.head(20).plot(kind='barh', x='Feature', y='Importance', figsize=(8,6), title='Top 20 Features')
plt.gca().invert_yaxis()
plt.show()
# Out:
#                                   Feature  Importance
# 1                                     Age   14.529996
# 9                        Work/Study Hours    9.764405
# 8   Have you ever had suicidal thoughts ?    8.893080
# 4                           Work Pressure    8.735987
# 6                        Job Satisfaction    8.105243
# 10                       Financial Stress    8.090206
# 32                            City_target    6.773731
# 31                      Profession_target    6.646198
# 7                          Sleep Duration    5.294855
# 30               Dietary Habits_Unhealthy    3.296472

# %%
test_df = pd.read_csv('~/Downloads/2025datathon/test.csv')

test = test_df.copy()

# %%
test.drop(columns=['id'], inplace=True)
test.drop(columns=['Name'], inplace=True)

# 1. CGPA 컬럼 제거
test.drop(columns=['CGPA'], inplace=True)

##### Sleep Duration ##### 
test['Sleep Duration'].value_counts()

# 이상치, 알 수 없는 값들 제거
delete_values = [
    'Indore', 'Pune', 'Moderate', 'Unhealthy', 'Sleep_Duration',
    'Work_Study_Hours', 'No', '45', '49 hours', '55-66 hours', '40-45 hours', 
    '9-5 hours', '10-6 hours', '9-6 hours', '9-5', '45-48 hours', '35-36 hours'
]

test['Sleep Duration'] = test['Sleep Duration'].replace(delete_values, np.nan)
test['Sleep Duration_missing'] = test['Sleep Duration'].isnull().astype(int)
mode_val = test["Sleep Duration"].mode()[0]
test["Sleep Duration"] = test["Sleep Duration"].fillna(mode_val)

import numpy as np
import re

def convert_sleep_to_hours(val):
    try:
        val = str(val).strip().lower()

        # 특별 처리: 'than n hours' → 'less than n hours' 간주
        if 'than' in val and 'less' not in val and 'more' not in val:
            match = re.search(r'\d+', val)
            if match:
                return float(match.group()) - 0.5

        # Less than n hours → n - 0.5
        if 'less than' in val:
            match = re.search(r'\d+', val)
            if match:
                return float(match.group()) - 0.5

        # More than n hours → n + 0.5
        elif 'more than' in val:
            match = re.search(r'\d+', val)
            if match:
                return float(match.group()) + 0.5

        # 정확히 n hours → 숫자만 추출
        elif re.match(r'^\d+\s*hours$', val):
            return float(re.findall(r'\d+', val)[0])

        # n-m hours 또는 n–n → 평균값
        elif re.search(r'\d+\s*[-–~]\s*\d+', val):
            nums = [int(n) for n in re.findall(r'\d+', val)]
            if len(nums) == 2:
                return sum(nums) / 2

        # 숫자만 → 그대로
        elif re.match(r'^\d+(\.\d+)?$', val):
            return float(val)

        # 나머지는 이상값으로 간주
        else:
            return np.nan

    except:
        return np.nan
test['Sleep Duration'] = test['Sleep Duration'].apply(convert_sleep_to_hours)

##### Sleep Duration ##### 
from sklearn.impute import SimpleImputer


# 2. Academic Pressure 결측 여부 파생 변수
test['Academic_Pressure_missing'] = test['Academic Pressure'].isnull().astype(int)

# 3. Study Satisfaction 결측 여부 파생 변수
test['Study_Satisfaction_missing'] = test['Study Satisfaction'].isnull().astype(int)

imputer = SimpleImputer(strategy='mean')  # 또는 'median', 'most_frequent'
test['Academic Pressure'] = imputer.fit_transform(test[['Academic Pressure']])
test['Study Satisfaction'] = imputer.fit_transform(test[['Study Satisfaction']])

# 4. Financial Stress
test['Financial Stress'] = test['Financial Stress'].fillna(2.0)

# 5. Work_Pressure
test['Work_Pressure_missing'] = test['Work Pressure'].isnull().astype(int)

# 6. Job_Satisfaction
test['Job_Satisfaction_missing'] = test['Job Satisfaction'].isnull().astype(int)

test['Work Pressure'] = imputer.fit_transform(test[['Work Pressure']])
test['Job Satisfaction'] = imputer.fit_transform(test[['Job Satisfaction']])

# 7. Profession
test['Profession'].fillna('Missing', inplace=True)

from sklearn.preprocessing import StandardScaler

scale_cols = ['Age', 'Sleep Duration', 'Work/Study Hours', 'Financial Stress']

scaler = StandardScaler()
test[scale_cols] = scaler.fit_transform(test[scale_cols])

# # 8. 
binary_cols = ['Have you ever had suicidal thoughts ?', 'Family History of Mental Illness']
for col in binary_cols:
    test[col] = test[col].map({'Yes': 1, 'No': 0})

# # 9. City
# 상위 15개 도시만 유지
top_cities = test['City'].value_counts().nlargest(15).index
test['City'] = test['City'].where(test['City'].isin(top_cities), other='Other')


# # Degree
test['Degree'].value_counts()

degree_group_map = {
    # 의학/보건
    'MD': 'Medical',
    'MBBS': 'Medical',
    'B.Pharm': 'Pharmacy',
    'M.Pharm': 'Pharmacy',
    'MPharm': 'Pharmacy',
    'P.Pharm': 'Pharmacy',
    'S.Pharm': 'Pharmacy',
    'N.Pharm': 'Pharmacy',

    # 공학/기술
    'B.Tech': 'Engineering',
    'M.Tech': 'Engineering',
    'ME': 'Engineering',
    'MTech': 'Engineering',
    'M_Tech': 'Engineering',
    'BE': 'Engineering',
    'BCA': 'Engineering',
    'MCA': 'Engineering',
    'E.Tech': 'Engineering',
    'S.Tech': 'Engineering',
    'LLTech': 'Engineering',
    'LLCom': 'Engineering',

    # 인문/사회/비즈니스
    'BBA': 'Business',
    'MBA': 'Business',
    'M. Business Analyst': 'Business',
    'B.Com': 'Commerce',
    'M.Com': 'Commerce',
    'P.Com': 'Commerce',
    'LLB': 'Law',
    'LLM': 'Law',
    'LLBA': 'Law',
    'LL.Com': 'Law',
    'LL B.Ed': 'Education',
    'B.Ed': 'Education',
    'M.Ed': 'Education',
    'L.Ed': 'Education',
    'K.Ed': 'Education',
    'LLEd': 'Education',
    'BEd': 'Education',

    # 과학
    'BSc': 'Science',
    'MSc': 'Science',
    'B.Sc': 'Science',

    # 기타, 건축, 호텔경영 등
    'BHM': 'Hospitality',
    'MHM': 'Hospitality',
    'B.Arch': 'Architecture',
    'M.Arch': 'Architecture',
    'BArch': 'Architecture',
    'B.B.Arch': 'Architecture',

    # 학위 및 학교 졸업
    'PhD': 'PhD',
    'Class 12': 'School',
    'Class 11': 'School',
}

test['degree_group'] =test['Degree'].apply(lambda x: degree_group_map.get(x, 'Other'))

test=test.drop('Degree',axis=1)


# # Dietary Habits
# 정상 값만 남기고 나머지는 NaN으로
valid_dietary = ['Moderate', 'Unhealthy', 'Healthy']
test['Dietary Habits'] = test['Dietary Habits'].where(test['Dietary Habits'].isin(valid_dietary))

# 결측값은 최빈값으로 대체
test['Dietary Habits'] = test['Dietary Habits'].fillna(test['Dietary Habits'].mode()[0])

# Gender, Working Status - Binary
test['Gender'] = test['Gender'].map({'Male': 1, 'Female': 0})
test['Working Professional or Student'] = test['Working Professional or Student'].map({'Working Professional': 1, 'Student': 0})

# Degree, Dietary Habits - One-hot encoding
test = pd.get_dummies(test, columns=['degree_group', 'Dietary Habits'], drop_first=True)


test['Profession_target'] = test['Profession'].map(profession_target_mean)
test['City_target'] = test['City'].map(city_target_mean)

# 이후 필요시 원본 컬럼 제거
test.drop(columns=['Profession', 'City'], inplace=True)
# Out:
# /var/folders/vp/r4ltbhf53594yjfl0f86yqv80000gp/T/ipykernel_88445/1701379026.py:96: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test['Profession'].fillna('Missing', inplace=True)

# %%
pred_submit = final_model.predict(test)

# %%
# 1. 샘플 제출 파일 불러오기
submission = pd.read_csv('~/Downloads/2025datathon/sample_submission.csv')

# 3. 예측 결과를 Depression 컬럼에 저장
submission['Depression'] = pred_submit

print(f"제출 파일의 shape: {submission.shape}")

# 4. 제출 파일 저장
submission.to_csv('submission_1_final_cat.csv', index=False)
# Out:
# 제출 파일의 shape: (93800, 2)
