# %%
import numpy as np
import pandas as pd
import os
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from imblearn.over_sampling import SMOTE

# %%
train = pd.read_csv('mental_train.csv')

# %%
train.head()
# Out:
#    id      Name  Gender   Age           City Working Professional or Student  \
# 0   0  Aaradhya  Female  49.0       Ludhiana            Working Professional
# 1   1     Vivan    Male  26.0       Varanasi            Working Professional
# 2   2    Yuvraj    Male  33.0  Visakhapatnam                         Student
# 3   3    Yuvraj    Male  22.0         Mumbai            Working Professional
# 4   4      Rhea  Female  30.0         Kanpur            Working Professional
#
#          Profession  Academic Pressure  Work Pressure  CGPA  \
# 0              Chef                NaN            5.0   NaN
# 1           Teacher                NaN            4.0   NaN
# 2               NaN                5.0            NaN  8.97
# 3           Teacher                NaN            5.0   NaN
# 4  Business Analyst                NaN            1.0   NaN
#
#    Study Satisfaction  Job Satisfaction     Sleep Duration Dietary Habits  \
# ...

# %%
sns.countplot(x='Depression', data=train)
# Out:
# <Axes: xlabel='Depression', ylabel='count'>

# %%
sns.countplot(x='Working Professional or Student', data=train)
# Out:
# <Axes: xlabel='Working Professional or Student', ylabel='count'>

# %%
sns.histplot(x='Age', bins=60, data=train, hue='Depression')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(x='Work/Study Hours', data=train, bins=30, hue='Depression')
# Out:
# <Axes: xlabel='Work/Study Hours', ylabel='Count'>

# %%
sns.countplot(x='Job Satisfaction', data=train, hue='Depression')
# Out:
# <Axes: xlabel='Job Satisfaction', ylabel='count'>

# %%
sns.countplot(x='Study Satisfaction', data=train, hue='Depression')
# Out:
# <Axes: xlabel='Study Satisfaction', ylabel='count'>

# %%
sns.countplot(x='Working Professional or Student', data=train, hue='Depression')
# Out:
# <Axes: xlabel='Working Professional or Student', ylabel='count'>

# %%
sns.countplot(x='Academic Pressure', hue='Depression', data=train)
# Out:
# <Axes: xlabel='Academic Pressure', ylabel='count'>

# %%
sns.countplot(x='Work Pressure', hue='Depression', data=train)
# Out:
# <Axes: xlabel='Work Pressure', ylabel='count'>

# %%
sns.countplot(x='Gender', hue='Depression', data=train)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.histplot(x='Age', bins=60, data=train, hue='Working Professional or Student')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.countplot(x='Family History of Mental Illness', data=train, hue='Depression')
# Out:
# <Axes: xlabel='Family History of Mental Illness', ylabel='count'>

# %%
sns.countplot(x='Financial Stress', data=train, hue='Depression')
# Out:
# <Axes: xlabel='Financial Stress', ylabel='count'>

# %%
histplot = sns.histplot(x='Profession', bins=120,data=train, hue='Depression')
plt.xticks(rotation=90)
barplot.set_xticklabels(barplot.get_xticklabels(), fontsize=6)
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 histplot = sns.histplot(x='Profession', bins=120,data=train, hue='Depression')
#       2 plt.xticks(rotation=90)
# ----> 3 barplot.set_xticklabels(barplot.get_xticklabels(), fontsize=6)
#       4 plt.tight_layout()
#
# NameError: name 'barplot' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 train['Profession'].sort_values().sum()
#
# File C:\ananconda3\Lib\site-packages\pandas\core\series.py:6528, in Series.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#    6519 @doc(make_doc("sum", ndim=1))
#    6520 def sum(
#    6521     self,
#    (...)
#    6526     **kwargs,
#    6527 ):
# -> 6528     return NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#
# File C:\ananconda3\Lib\site-packages\pandas\core\generic.py:12506, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12498 def sum(
#   12499     self,
#   12500     axis: Axis | None = 0,
#    (...)
#   12504     **kwargs,
#   12505 ):
# > 12506     return self._min_count_stat_function(
#   12507         "sum", nanops.nansum, axis, skipna, numeric_only, min_count, **kwargs
# ...
